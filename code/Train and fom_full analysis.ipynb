# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os, sys
import numpy as np
import helper
import tensorflow as tf
from deepomics import neuralnetwork as nn
from deepomics import utils, fit


all_models = ['DistNet', 'LocalNet', 'DeepBind', 'StandardNet']
num_models = len(all_models)
dropout_status = [True, True, 	False, 	False, 	False, True,  True,  False]
l2_status = 	 [True, False, 	True, 	False, 	False, True,  False, True]
bn_status = 	 [True, False, 	False, 	True, 	False, False, True,  True]
num_reg = len(dropout_status)

Names = []
# loop through models
for t, model_name in enumerate(all_models): 
    #Names[t] = []
    #loop through every regularization type
    modelsreg = []
    for i in range(len(dropout_status)):

        # compile neural trainer
        name = model_name
        if dropout_status[i]:
            name += '_do'
        if l2_status[i]:
            name += '_l2'
        if bn_status[i]:
            name += '_bn'
        modelsreg.append(name)
        #Names[t].append(name)
    Names.append(modelsreg)

# %%
import pandas as pd
pd.DataFrame(Names)
# Out:
#                       0               1               2               3  \
# 0      DistNet_do_l2_bn      DistNet_do      DistNet_l2      DistNet_bn
# 1     LocalNet_do_l2_bn     LocalNet_do     LocalNet_l2     LocalNet_bn
# 2     DeepBind_do_l2_bn     DeepBind_do     DeepBind_l2     DeepBind_bn
# 3  StandardNet_do_l2_bn  StandardNet_do  StandardNet_l2  StandardNet_bn
#
#              4                  5                  6                  7
# 0      DistNet      DistNet_do_l2      DistNet_do_bn      DistNet_l2_bn
# 1     LocalNet     LocalNet_do_l2     LocalNet_do_bn     LocalNet_l2_bn
# 2     DeepBind     DeepBind_do_l2     DeepBind_do_bn     DeepBind_l2_bn
# 3  StandardNet  StandardNet_do_l2  StandardNet_do_bn  StandardNet_l2_bn

# %%
analysis_idx = {}
for m, model in enumerate(Names):
    for r, reg in enumerate(model):
        analysis_idx[reg] = [m,r]

# %%
analysis_idx
# Out:
# {'DeepBind': [2, 4],
#  'DeepBind_bn': [2, 3],
#  'DeepBind_do': [2, 1],
#  'DeepBind_do_bn': [2, 6],
#  'DeepBind_do_l2': [2, 5],
#  'DeepBind_do_l2_bn': [2, 0],
#  'DeepBind_l2': [2, 2],
#  'DeepBind_l2_bn': [2, 7],
#  'DistNet': [0, 4],
#  'DistNet_bn': [0, 3],
#  'DistNet_do': [0, 1],
#  'DistNet_do_bn': [0, 6],
#  'DistNet_do_l2': [0, 5],
#  'DistNet_do_l2_bn': [0, 0],
#  'DistNet_l2': [0, 2],
#  'DistNet_l2_bn': [0, 7],
#  'LocalNet': [1, 4],
#  'LocalNet_bn': [1, 3],
#  'LocalNet_do': [1, 1],
#  'LocalNet_do_bn': [1, 6],
#  'LocalNet_do_l2': [1, 5],
#  'LocalNet_do_l2_bn': [1, 0],
#  'LocalNet_l2': [1, 2],
#  'LocalNet_l2_bn': [1, 7],
#  'StandardNet': [3, 4],
#  'StandardNet_bn': [3, 3],
#  'StandardNet_do': [3, 1],
#  'StandardNet_do_bn': [3, 6],
#  'StandardNet_do_l2': [3, 5],
#  'StandardNet_do_l2_bn': [3, 0],
#  'StandardNet_l2': [3, 2],
#  'StandardNet_l2_bn': [3, 7]}

# %%
# save path
results_path = '../results'
params_path = utils.make_directory(results_path, 'model_params')

# dataset path
data_path = '../data/Synthetic_dataset.h5'

# load dataset
train, valid, test = helper.load_synthetic_dataset(data_path)
#Get the indices of correctly labelled sequences
right_index = np.where(train['targets'][:,0]==1)[0]
num_pos = len(right_index)
# Out:
# loading training data
# loading cross-validation data
# loading test data

# %%
np.zeros((2,4))
# Out:
# array([[0., 0., 0., 0.],
#        [0., 0., 0., 0.]])

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os, sys
import numpy as np
import helper
import tensorflow as tf
from deepomics import neuralnetwork as nn
from deepomics import utils, fit

#------------------------------------------------------------------------------------------------

#all_models = ['DistNet', 'LocalNet', 'DeepBind', 'StandardNet']
#dropout_status = [True, True, 	False, 	False, 	False, True,  True,  False]
#l2_status = 	 [True, False, 	True, 	False, 	False, True,  False, True]
#bn_status = 	 [True, False, 	False, 	True, 	False, False, True,  True]

all_models = ['LocalNet']
dropout_status = [True]
l2_status = 	 [True]
bn_status = 	 [True]


# save path
results_path = '../results'
params_path = utils.make_directory(results_path, 'model_params')

# dataset path
data_path = '../data/Synthetic_dataset.h5'

# load dataset
train, valid, test = helper.load_synthetic_dataset(data_path)

# get data shapes
input_shape = list(train['inputs'].shape)
input_shape[0] = None


for i in range(len(dropout_status)):

	# loop through models
	for model_name in all_models:
		tf.reset_default_graph()
		print('model: ' + model_name)

		# compile neural trainer
		name = model_name
		if dropout_status[i]:
			name += '_do'
		if l2_status[i]:
			name += '_l2'
		if bn_status[i]:
			name += '_bn'
		name+= 'seed247'
		model_path = utils.make_directory(params_path, model_name)
		file_path = os.path.join(model_path, name)

		# load model parameters
		model_layers, optimization, _ = helper.load_model(model_name, 
														  input_shape,
														  dropout_status[i], 
														  l2_status[i], 
														  bn_status[i])

		# build neural network class
		nnmodel = nn.NeuralNet(seed=247)
		nnmodel.build_layers(model_layers, optimization, supervised=True)

		nntrainer = nn.NeuralTrainer(nnmodel, save='best', file_path=file_path)

		# initialize session
		sess = utils.initialize_session()

		# set data in dictionary
		data = {'train': train, 'valid': valid, 'test': test}
		fit.train_minibatch(sess, nntrainer, data, batch_size=100, num_epochs=100, 
							patience=100, verbose=2, shuffle=True, save_all=False)
# Out:
# loading training data
# loading cross-validation data
# loading test data
# model: LocalNet
# Epoch 1 out of 100
# [==============================] 100.0% -- elapsed time=1.51s -- loss=0.75008 -- acc=54.842854%
#
#   valid loss:		0.72677
#   valid accuracy:	0.54767+/-0.00000
#   valid auc-roc:	0.77338+/-0.00000
#   valid auc-pr:		0.76437+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/model_params/LocalNet/LocalNet_do_l2_bnseed247_best.ckpt
# Epoch 2 out of 100
# [==============================] 100.0% -- elapsed time=1.03s -- loss=0.62948 -- acc=64.852385%
#
#   valid loss:		0.54204
#   valid accuracy:	0.73333+/-0.00000
#   valid auc-roc:	0.84680+/-0.00000
#   valid auc-pr:		0.84097+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/model_params/LocalNet/LocalNet_do_l2_bnseed247_best.ckpt
# Epoch 3 out of 100
# [==============================] 100.0% -- elapsed time=1.05s -- loss=0.56832 -- acc=70.576198%
#
#   valid loss:		0.48715
#   valid accuracy:	0.77933+/-0.00000
#   valid auc-roc:	0.87462+/-0.00000
#   valid auc-pr:		0.87351+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/model_params/LocalNet/LocalNet_do_l2_bnseed247_best.ckpt
# Epoch 4 out of 100
# [==============================] 100.0% -- elapsed time=1.05s -- loss=0.53449 -- acc=73.200000%
#
#   valid loss:		0.45475
#   valid accuracy:	0.79767+/-0.00000
#   valid auc-roc:	0.89033+/-0.00000
#   valid auc-pr:		0.89137+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/model_params/LocalNet/LocalNet_do_l2_bnseed247_best.ckpt
# Epoch 5 out of 100
# [==============================] 100.0% -- elapsed time=1.06s -- loss=0.51139 -- acc=75.147625%
#
#   valid loss:		0.43103
#   valid accuracy:	0.81367+/-0.00000
#   valid auc-roc:	0.90103+/-0.00000
#   valid auc-pr:		0.90247+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/model_params/LocalNet/LocalNet_do_l2_bnseed247_best.ckpt
# Epoch 6 out of 100
# [==============================] 100.0% -- elapsed time=1.06s -- loss=0.49223 -- acc=76.247625%
#
#   valid loss:		0.44550
#   valid accuracy:	0.79800+/-0.00000
#   valid auc-roc:	0.90658+/-0.00000
#   valid auc-pr:		0.90899+/-0.00000
# Epoch 7 out of 100
# [==============================] 100.0% -- elapsed time=1.05s -- loss=0.47133 -- acc=77.633333%
#
#   valid loss:		0.41730
#   valid accuracy:	0.81633+/-0.00000
#   valid auc-roc:	0.91428+/-0.00000
#   valid auc-pr:		0.91656+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/model_params/LocalNet/LocalNet_do_l2_bnseed247_best.ckpt
# Epoch 8 out of 100
# [==============================] 100.0% -- elapsed time=1.07s -- loss=0.45530 -- acc=78.561906%
#
#   valid loss:		0.42944
#   valid accuracy:	0.80733+/-0.00000
#   valid auc-roc:	0.92084+/-0.00000
#   valid auc-pr:		0.92387+/-0.00000
# Epoch 9 out of 100
# [==============================] 100.0% -- elapsed time=1.06s -- loss=0.41945 -- acc=80.919052%
#
#   valid loss:		0.46655
#   valid accuracy:	0.76067+/-0.00000
#   valid auc-roc:	0.92832+/-0.00000
#   valid auc-pr:		0.93044+/-0.00000
# Epoch 10 out of 100
# [==============================] 100.0% -- elapsed time=1.06s -- loss=0.38394 -- acc=82.728573%
#
#   valid loss:		0.36729
#   valid accuracy:	0.83933+/-0.00000
#   valid auc-roc:	0.94308+/-0.00000
#   valid auc-pr:		0.94386+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/model_params/LocalNet/LocalNet_do_l2_bnseed247_best.ckpt
# Epoch 11 out of 100
# [==============================] 100.0% -- elapsed time=0.99s -- loss=0.34965 -- acc=84.704760%
#
#   valid loss:		0.31561
#   valid accuracy:	0.87967+/-0.00000
#   valid auc-roc:	0.95141+/-0.00000
#   valid auc-pr:		0.95131+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/model_params/LocalNet/LocalNet_do_l2_bnseed247_best.ckpt
# Epoch 12 out of 100
# [==============================] 100.0% -- elapsed time=0.99s -- loss=0.31905 -- acc=86.347625%
#
#   valid loss:		0.29809
#   valid accuracy:	0.88400+/-0.00000
#   valid auc-roc:	0.95719+/-0.00000
#   valid auc-pr:		0.95732+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/model_params/LocalNet/LocalNet_do_l2_bnseed247_best.ckpt
# Epoch 13 out of 100
# [==============================] 100.0% -- elapsed time=1.07s -- loss=0.30244 -- acc=87.252385%
#
#   valid loss:		0.26542
#   valid accuracy:	0.88967+/-0.00000
#   valid auc-roc:	0.96055+/-0.00000
#   valid auc-pr:		0.96092+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/model_params/LocalNet/LocalNet_do_l2_bnseed247_best.ckpt
# Epoch 14 out of 100
# [==============================] 100.0% -- elapsed time=1.10s -- loss=0.29254 -- acc=87.890489%
#
#   valid loss:		0.25536
#   valid accuracy:	0.89567+/-0.00000
#   valid auc-roc:	0.96468+/-0.00000
#   valid auc-pr:		0.96363+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/model_params/LocalNet/LocalNet_do_l2_bnseed247_best.ckpt
# Epoch 15 out of 100
# [==============================] 100.0% -- elapsed time=1.07s -- loss=0.27620 -- acc=88.709531%
#
#   valid loss:		0.24053
#   valid accuracy:	0.89600+/-0.00000
#   valid auc-roc:	0.96661+/-0.00000
#   valid auc-pr:		0.96620+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/model_params/LocalNet/LocalNet_do_l2_bnseed247_best.ckpt
# Epoch 16 out of 100
# [==============================] 100.0% -- elapsed time=1.06s -- loss=0.26794 -- acc=88.733333%
#
#   valid loss:		0.23559
#   valid accuracy:	0.90167+/-0.00000
#   valid auc-roc:	0.96683+/-0.00000
#   valid auc-pr:		0.96649+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/model_params/LocalNet/LocalNet_do_l2_bnseed247_best.ckpt
# Epoch 17 out of 100
# [==============================] 100.0% -- elapsed time=1.07s -- loss=0.26023 -- acc=89.152385%
#
#   valid loss:		0.23274
#   valid accuracy:	0.90600+/-0.00000
#   valid auc-roc:	0.96890+/-0.00000
#   valid auc-pr:		0.96799+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/model_params/LocalNet/LocalNet_do_l2_bnseed247_best.ckpt
# Epoch 18 out of 100
# [==============================] 100.0% -- elapsed time=1.07s -- loss=0.25818 -- acc=89.419052%
#
#   valid loss:		0.22701
#   valid accuracy:	0.90633+/-0.00000
#   valid auc-roc:	0.96895+/-0.00000
#   valid auc-pr:		0.96889+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/model_params/LocalNet/LocalNet_do_l2_bnseed247_best.ckpt
# Epoch 19 out of 100
# [==============================] 100.0% -- elapsed time=1.07s -- loss=0.24624 -- acc=90.057146%
#
#   valid loss:		0.21802
#   valid accuracy:	0.90900+/-0.00000
#   valid auc-roc:	0.97115+/-0.00000
#   valid auc-pr:		0.97098+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/model_params/LocalNet/LocalNet_do_l2_bnseed247_best.ckpt
# Epoch 20 out of 100
# [==============================] 100.0% -- elapsed time=1.09s -- loss=0.24498 -- acc=90.023812%
#
#   valid loss:		0.21878
#   valid accuracy:	0.90900+/-0.00000
#   valid auc-roc:	0.97158+/-0.00000
#   valid auc-pr:		0.97197+/-0.00000
# Epoch 21 out of 100
# [==============================] 100.0% -- elapsed time=1.07s -- loss=0.23919 -- acc=90.166677%
#
#   valid loss:		0.21447
#   valid accuracy:	0.91333+/-0.00000
#   valid auc-roc:	0.97237+/-0.00000
#   valid auc-pr:		0.97226+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/model_params/LocalNet/LocalNet_do_l2_bnseed247_best.ckpt
# Epoch 22 out of 100
# [==============================] 100.0% -- elapsed time=1.09s -- loss=0.24269 -- acc=90.033333%
#
#   valid loss:		0.21991
#   valid accuracy:	0.91200+/-0.00000
#   valid auc-roc:	0.97107+/-0.00000
#   valid auc-pr:		0.97071+/-0.00000
# Epoch 23 out of 100
# [==============================] 100.0% -- elapsed time=1.09s -- loss=0.23954 -- acc=90.157146%
#
#   valid loss:		0.22665
#   valid accuracy:	0.90233+/-0.00000
#   valid auc-roc:	0.97058+/-0.00000
#   valid auc-pr:		0.97011+/-0.00000
# Epoch 24 out of 100
# [==============================] 100.0% -- elapsed time=1.06s -- loss=0.23607 -- acc=90.504760%
#
#   valid loss:		0.21794
#   valid accuracy:	0.90833+/-0.00000
#   valid auc-roc:	0.97095+/-0.00000
#   valid auc-pr:		0.97073+/-0.00000
# Epoch 25 out of 100
# [==============================] 100.0% -- elapsed time=1.07s -- loss=0.23140 -- acc=90.304760%
#
#   valid loss:		0.21798
#   valid accuracy:	0.90933+/-0.00000
#   valid auc-roc:	0.97095+/-0.00000
#   valid auc-pr:		0.97091+/-0.00000
# Epoch 26 out of 100
# [==============================] 100.0% -- elapsed time=1.07s -- loss=0.22748 -- acc=90.952385%
#
#   valid loss:		0.22229
#   valid accuracy:	0.90800+/-0.00000
#   valid auc-roc:	0.97039+/-0.00000
#   valid auc-pr:		0.97009+/-0.00000
# Epoch 27 out of 100
# [==============================] 100.0% -- elapsed time=1.07s -- loss=0.22936 -- acc=90.776198%
#
#   valid loss:		0.21480
#   valid accuracy:	0.91000+/-0.00000
#   valid auc-roc:	0.97223+/-0.00000
#   valid auc-pr:		0.97201+/-0.00000
# Epoch 28 out of 100
# [==============================] 100.0% -- elapsed time=1.06s -- loss=0.23079 -- acc=90.452385%
#
#   valid loss:		0.20998
#   valid accuracy:	0.91467+/-0.00000
#   valid auc-roc:	0.97374+/-0.00000
#   valid auc-pr:		0.97361+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/model_params/LocalNet/LocalNet_do_l2_bnseed247_best.ckpt
# Epoch 29 out of 100
# [==============================] 100.0% -- elapsed time=1.11s -- loss=0.22748 -- acc=90.861916%
#
#   valid loss:		0.20706
#   valid accuracy:	0.91200+/-0.00000
#   valid auc-roc:	0.97426+/-0.00000
#   valid auc-pr:		0.97456+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/model_params/LocalNet/LocalNet_do_l2_bnseed247_best.ckpt
# Epoch 30 out of 100
# [==============================] 100.0% -- elapsed time=1.10s -- loss=0.22404 -- acc=90.871437%
#
#   valid loss:		0.20960
#   valid accuracy:	0.91533+/-0.00000
#   valid auc-roc:	0.97382+/-0.00000
#   valid auc-pr:		0.97386+/-0.00000
# Epoch 31 out of 100
# [==============================] 100.0% -- elapsed time=1.08s -- loss=0.22297 -- acc=90.971437%
#
#   valid loss:		0.21201
#   valid accuracy:	0.91067+/-0.00000
#   valid auc-roc:	0.97304+/-0.00000
#   valid auc-pr:		0.97314+/-0.00000
# Epoch 32 out of 100
# [==============================] 100.0% -- elapsed time=1.08s -- loss=0.22561 -- acc=90.919052%
#
#   valid loss:		0.21108
#   valid accuracy:	0.91433+/-0.00000
#   valid auc-roc:	0.97318+/-0.00000
#   valid auc-pr:		0.97360+/-0.00000
# Epoch 33 out of 100
# [==============================] 100.0% -- elapsed time=1.07s -- loss=0.22490 -- acc=90.966677%
#
#   valid loss:		0.20700
#   valid accuracy:	0.91367+/-0.00000
#   valid auc-roc:	0.97391+/-0.00000
#   valid auc-pr:		0.97369+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/model_params/LocalNet/LocalNet_do_l2_bnseed247_best.ckpt
# Epoch 34 out of 100
# [==============================] 100.0% -- elapsed time=1.08s -- loss=0.22575 -- acc=90.809531%
#
#   valid loss:		0.20931
#   valid accuracy:	0.91533+/-0.00000
#   valid auc-roc:	0.97437+/-0.00000
#   valid auc-pr:		0.97461+/-0.00000
# Epoch 35 out of 100
# [==============================] 100.0% -- elapsed time=1.06s -- loss=0.22148 -- acc=91.066677%
#
#   valid loss:		0.20656
#   valid accuracy:	0.91367+/-0.00000
#   valid auc-roc:	0.97460+/-0.00000
#   valid auc-pr:		0.97413+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/model_params/LocalNet/LocalNet_do_l2_bnseed247_best.ckpt
# Epoch 36 out of 100
# [==============================] 100.0% -- elapsed time=1.07s -- loss=0.22015 -- acc=90.847625%
#
#   valid loss:		0.20882
#   valid accuracy:	0.91400+/-0.00000
#   valid auc-roc:	0.97324+/-0.00000
#   valid auc-pr:		0.97289+/-0.00000
# Epoch 37 out of 100
# [==============================] 100.0% -- elapsed time=1.06s -- loss=0.21721 -- acc=91.238104%
#
#   valid loss:		0.20526
#   valid accuracy:	0.91600+/-0.00000
#   valid auc-roc:	0.97428+/-0.00000
#   valid auc-pr:		0.97419+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/model_params/LocalNet/LocalNet_do_l2_bnseed247_best.ckpt
# Epoch 38 out of 100
# [==============================] 100.0% -- elapsed time=1.08s -- loss=0.21928 -- acc=91.123812%
#
#   valid loss:		0.20282
#   valid accuracy:	0.91633+/-0.00000
#   valid auc-roc:	0.97487+/-0.00000
#   valid auc-pr:		0.97484+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/model_params/LocalNet/LocalNet_do_l2_bnseed247_best.ckpt
# Epoch 39 out of 100
# [==============================] 100.0% -- elapsed time=1.07s -- loss=0.21923 -- acc=91.247625%
#
#   valid loss:		0.20889
#   valid accuracy:	0.91000+/-0.00000
#   valid auc-roc:	0.97385+/-0.00000
#   valid auc-pr:		0.97341+/-0.00000
# Epoch 40 out of 100
# [==============================] 100.0% -- elapsed time=1.05s -- loss=0.21626 -- acc=91.285729%
#
#   valid loss:		0.20792
#   valid accuracy:	0.91600+/-0.00000
#   valid auc-roc:	0.97460+/-0.00000
#   valid auc-pr:		0.97416+/-0.00000
# Epoch 41 out of 100
# [==============================] 100.0% -- elapsed time=1.06s -- loss=0.22250 -- acc=91.190489%
#
#   valid loss:		0.20644
#   valid accuracy:	0.91733+/-0.00000
#   valid auc-roc:	0.97424+/-0.00000
#   valid auc-pr:		0.97391+/-0.00000
# Epoch 42 out of 100
# [==============================] 100.0% -- elapsed time=1.06s -- loss=0.21774 -- acc=91.090489%
#
#   valid loss:		0.20591
#   valid accuracy:	0.91667+/-0.00000
#   valid auc-roc:	0.97509+/-0.00000
#   valid auc-pr:		0.97482+/-0.00000
# Epoch 43 out of 100
# [==============================] 100.0% -- elapsed time=1.08s -- loss=0.21868 -- acc=91.152385%
#
#   valid loss:		0.20077
#   valid accuracy:	0.91867+/-0.00000
#   valid auc-roc:	0.97563+/-0.00000
#   valid auc-pr:		0.97570+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/model_params/LocalNet/LocalNet_do_l2_bnseed247_best.ckpt
# Epoch 44 out of 100
# [==============================] 100.0% -- elapsed time=1.07s -- loss=0.22030 -- acc=91.071437%
#
#   valid loss:		0.20424
#   valid accuracy:	0.91233+/-0.00000
#   valid auc-roc:	0.97522+/-0.00000
#   valid auc-pr:		0.97506+/-0.00000
# Epoch 45 out of 100
# [==============================] 100.0% -- elapsed time=1.06s -- loss=0.21792 -- acc=91.328573%
#
#   valid loss:		0.19703
#   valid accuracy:	0.92067+/-0.00000
#   valid auc-roc:	0.97641+/-0.00000
#   valid auc-pr:		0.97623+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/model_params/LocalNet/LocalNet_do_l2_bnseed247_best.ckpt
# Epoch 46 out of 100
# [==============================] 100.0% -- elapsed time=1.05s -- loss=0.21476 -- acc=91.447625%
#
#   valid loss:		0.20124
#   valid accuracy:	0.91467+/-0.00000
#   valid auc-roc:	0.97525+/-0.00000
#   valid auc-pr:		0.97515+/-0.00000
# Epoch 47 out of 100
# [==============================] 100.0% -- elapsed time=1.04s -- loss=0.21434 -- acc=91.490489%
#
#   valid loss:		0.20004
#   valid accuracy:	0.91933+/-0.00000
#   valid auc-roc:	0.97574+/-0.00000
#   valid auc-pr:		0.97576+/-0.00000
# Epoch 48 out of 100
# [==============================] 100.0% -- elapsed time=1.11s -- loss=0.21514 -- acc=91.490489%
#
#   valid loss:		0.19737
#   valid accuracy:	0.92133+/-0.00000
#   valid auc-roc:	0.97650+/-0.00000
#   valid auc-pr:		0.97633+/-0.00000
# Epoch 49 out of 100
# [==============================] 100.0% -- elapsed time=1.08s -- loss=0.21794 -- acc=91.185729%
#
#   valid loss:		0.20410
#   valid accuracy:	0.91400+/-0.00000
#   valid auc-roc:	0.97622+/-0.00000
#   valid auc-pr:		0.97600+/-0.00000
# Epoch 50 out of 100
# [==============================] 100.0% -- elapsed time=1.06s -- loss=0.20737 -- acc=91.780968%
#
#   valid loss:		0.19775
#   valid accuracy:	0.91533+/-0.00000
#   valid auc-roc:	0.97623+/-0.00000
#   valid auc-pr:		0.97618+/-0.00000
# Epoch 51 out of 100
# [==============================] 100.0% -- elapsed time=1.08s -- loss=0.21491 -- acc=91.419052%
#
#   valid loss:		0.19797
#   valid accuracy:	0.91667+/-0.00000
#   valid auc-roc:	0.97667+/-0.00000
#   valid auc-pr:		0.97693+/-0.00000
# Epoch 52 out of 100
# [==============================] 100.0% -- elapsed time=1.08s -- loss=0.20954 -- acc=91.542864%
#
#   valid loss:		0.19735
#   valid accuracy:	0.91800+/-0.00000
#   valid auc-roc:	0.97639+/-0.00000
#   valid auc-pr:		0.97639+/-0.00000
# Epoch 53 out of 100
# [==============================] 100.0% -- elapsed time=1.08s -- loss=0.21246 -- acc=91.371437%
#
#   valid loss:		0.19314
#   valid accuracy:	0.92267+/-0.00000
#   valid auc-roc:	0.97736+/-0.00000
#   valid auc-pr:		0.97745+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/model_params/LocalNet/LocalNet_do_l2_bnseed247_best.ckpt
# Epoch 54 out of 100
# [==============================] 100.0% -- elapsed time=1.06s -- loss=0.21402 -- acc=91.371437%
#
#   valid loss:		0.19546
#   valid accuracy:	0.91767+/-0.00000
#   valid auc-roc:	0.97698+/-0.00000
#   valid auc-pr:		0.97701+/-0.00000
# Epoch 55 out of 100
# [==============================] 100.0% -- elapsed time=1.06s -- loss=0.21017 -- acc=91.585729%
#
#   valid loss:		0.19697
#   valid accuracy:	0.91900+/-0.00000
#   valid auc-roc:	0.97640+/-0.00000
#   valid auc-pr:		0.97661+/-0.00000
# Epoch 56 out of 100
# [==============================] 100.0% -- elapsed time=1.06s -- loss=0.20641 -- acc=91.714291%
#
#   valid loss:		0.19091
#   valid accuracy:	0.92367+/-0.00000
#   valid auc-roc:	0.97791+/-0.00000
#   valid auc-pr:		0.97809+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/model_params/LocalNet/LocalNet_do_l2_bnseed247_best.ckpt
# Epoch 57 out of 100
# [==============================] 100.0% -- elapsed time=1.08s -- loss=0.20620 -- acc=91.752385%
#
#   valid loss:		0.19804
#   valid accuracy:	0.92133+/-0.00000
#   valid auc-roc:	0.97674+/-0.00000
#   valid auc-pr:		0.97700+/-0.00000
# Epoch 58 out of 100
# [==============================] 100.0% -- elapsed time=1.07s -- loss=0.21184 -- acc=91.528573%
#
#   valid loss:		0.19705
#   valid accuracy:	0.92100+/-0.00000
#   valid auc-roc:	0.97744+/-0.00000
#   valid auc-pr:		0.97774+/-0.00000
# Epoch 59 out of 100
# [==============================] 100.0% -- elapsed time=1.07s -- loss=0.20791 -- acc=91.828573%
#
#   valid loss:		0.19474
#   valid accuracy:	0.92300+/-0.00000
#   valid auc-roc:	0.97710+/-0.00000
#   valid auc-pr:		0.97718+/-0.00000
# Epoch 60 out of 100
# [==============================] 100.0% -- elapsed time=1.06s -- loss=0.20951 -- acc=91.552385%
#
#   valid loss:		0.19406
#   valid accuracy:	0.91867+/-0.00000
#   valid auc-roc:	0.97723+/-0.00000
#   valid auc-pr:		0.97725+/-0.00000
# Epoch 61 out of 100
# [==============================] 100.0% -- elapsed time=1.05s -- loss=0.20609 -- acc=91.785729%
#
#   valid loss:		0.19233
#   valid accuracy:	0.91867+/-0.00000
#   valid auc-roc:	0.97758+/-0.00000
#   valid auc-pr:		0.97770+/-0.00000
# Epoch 62 out of 100
# [==============================] 100.0% -- elapsed time=1.07s -- loss=0.20404 -- acc=91.895240%
#
#   valid loss:		0.19300
#   valid accuracy:	0.92200+/-0.00000
#   valid auc-roc:	0.97734+/-0.00000
#   valid auc-pr:		0.97760+/-0.00000
# Epoch 63 out of 100
# [==============================] 100.0% -- elapsed time=1.06s -- loss=0.20661 -- acc=91.776198%
#
#   valid loss:		0.19726
#   valid accuracy:	0.91800+/-0.00000
#   valid auc-roc:	0.97751+/-0.00000
#   valid auc-pr:		0.97765+/-0.00000
# Epoch 64 out of 100
# [==============================] 100.0% -- elapsed time=1.06s -- loss=0.20106 -- acc=91.919052%
#
#   valid loss:		0.20281
#   valid accuracy:	0.91667+/-0.00000
#   valid auc-roc:	0.97736+/-0.00000
#   valid auc-pr:		0.97738+/-0.00000
# Epoch 65 out of 100
# [==============================] 100.0% -- elapsed time=1.06s -- loss=0.20759 -- acc=91.838104%
#
#   valid loss:		0.19323
#   valid accuracy:	0.92133+/-0.00000
#   valid auc-roc:	0.97754+/-0.00000
#   valid auc-pr:		0.97751+/-0.00000
# Epoch 66 out of 100
# [==============================] 100.0% -- elapsed time=1.05s -- loss=0.20315 -- acc=91.852385%
#
#   valid loss:		0.19558
#   valid accuracy:	0.92233+/-0.00000
#   valid auc-roc:	0.97680+/-0.00000
#   valid auc-pr:		0.97676+/-0.00000
# Epoch 67 out of 100
# [==============================] 100.0% -- elapsed time=1.08s -- loss=0.20385 -- acc=91.871437%
#
#   valid loss:		0.19466
#   valid accuracy:	0.91967+/-0.00000
#   valid auc-roc:	0.97725+/-0.00000
#   valid auc-pr:		0.97730+/-0.00000
# Epoch 68 out of 100
# [==============================] 100.0% -- elapsed time=1.08s -- loss=0.20465 -- acc=91.938104%
#
#   valid loss:		0.19029
#   valid accuracy:	0.91967+/-0.00000
#   valid auc-roc:	0.97805+/-0.00000
#   valid auc-pr:		0.97842+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/model_params/LocalNet/LocalNet_do_l2_bnseed247_best.ckpt
# Epoch 69 out of 100
# [==============================] 100.0% -- elapsed time=1.07s -- loss=0.20404 -- acc=91.776198%
#
#   valid loss:		0.19295
#   valid accuracy:	0.92100+/-0.00000
#   valid auc-roc:	0.97736+/-0.00000
#   valid auc-pr:		0.97707+/-0.00000
# Epoch 70 out of 100
# [==============================] 100.0% -- elapsed time=1.06s -- loss=0.19900 -- acc=92.104760%
#
#   valid loss:		0.19127
#   valid accuracy:	0.91867+/-0.00000
#   valid auc-roc:	0.97813+/-0.00000
#   valid auc-pr:		0.97790+/-0.00000
# Epoch 71 out of 100
# [==============================] 100.0% -- elapsed time=1.06s -- loss=0.20366 -- acc=91.719052%
#
#   valid loss:		0.18760
#   valid accuracy:	0.91933+/-0.00000
#   valid auc-roc:	0.97878+/-0.00000
#   valid auc-pr:		0.97899+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/model_params/LocalNet/LocalNet_do_l2_bnseed247_best.ckpt
# Epoch 72 out of 100
# [==============================] 100.0% -- elapsed time=1.08s -- loss=0.20411 -- acc=91.704770%
#
#   valid loss:		0.18841
#   valid accuracy:	0.92167+/-0.00000
#   valid auc-roc:	0.97870+/-0.00000
#   valid auc-pr:		0.97915+/-0.00000
# Epoch 73 out of 100
# [==============================] 100.0% -- elapsed time=1.08s -- loss=0.19857 -- acc=92.223812%
#
#   valid loss:		0.19043
#   valid accuracy:	0.92000+/-0.00000
#   valid auc-roc:	0.97794+/-0.00000
#   valid auc-pr:		0.97811+/-0.00000
# Epoch 74 out of 100
# [==============================] 100.0% -- elapsed time=1.06s -- loss=0.20394 -- acc=91.914291%
#
#   valid loss:		0.19343
#   valid accuracy:	0.92000+/-0.00000
#   valid auc-roc:	0.97731+/-0.00000
#   valid auc-pr:		0.97728+/-0.00000
# Epoch 75 out of 100
# [==============================] 100.0% -- elapsed time=1.09s -- loss=0.20364 -- acc=91.771437%
#
#   valid loss:		0.19477
#   valid accuracy:	0.92200+/-0.00000
#   valid auc-roc:	0.97685+/-0.00000
#   valid auc-pr:		0.97657+/-0.00000
# Epoch 76 out of 100
# [==============================] 100.0% -- elapsed time=1.07s -- loss=0.20264 -- acc=92.004760%
#
#   valid loss:		0.19269
#   valid accuracy:	0.92367+/-0.00000
#   valid auc-roc:	0.97768+/-0.00000
#   valid auc-pr:		0.97750+/-0.00000
# Epoch 77 out of 100
# [==============================] 100.0% -- elapsed time=1.09s -- loss=0.19669 -- acc=92.090489%
#
#   valid loss:		0.18862
#   valid accuracy:	0.92400+/-0.00000
#   valid auc-roc:	0.97843+/-0.00000
#   valid auc-pr:		0.97865+/-0.00000
# Epoch 78 out of 100
# [==============================] 100.0% -- elapsed time=1.08s -- loss=0.19808 -- acc=92.152385%
#
#   valid loss:		0.18884
#   valid accuracy:	0.92633+/-0.00000
#   valid auc-roc:	0.97835+/-0.00000
#   valid auc-pr:		0.97856+/-0.00000
# Epoch 79 out of 100
# [==============================] 100.0% -- elapsed time=1.05s -- loss=0.20266 -- acc=91.919052%
#
#   valid loss:		0.18825
#   valid accuracy:	0.92300+/-0.00000
#   valid auc-roc:	0.97860+/-0.00000
#   valid auc-pr:		0.97856+/-0.00000
# Epoch 80 out of 100
# [==============================] 100.0% -- elapsed time=1.06s -- loss=0.19918 -- acc=91.938104%
#
#   valid loss:		0.19346
#   valid accuracy:	0.92067+/-0.00000
#   valid auc-roc:	0.97724+/-0.00000
#   valid auc-pr:		0.97693+/-0.00000
# Epoch 81 out of 100
# [==============================] 100.0% -- elapsed time=1.06s -- loss=0.19858 -- acc=92.119052%
#
#   valid loss:		0.19033
#   valid accuracy:	0.92300+/-0.00000
#   valid auc-roc:	0.97804+/-0.00000
#   valid auc-pr:		0.97768+/-0.00000
# Epoch 82 out of 100
# [==============================] 100.0% -- elapsed time=1.07s -- loss=0.20232 -- acc=91.914291%
#
#   valid loss:		0.19370
#   valid accuracy:	0.92000+/-0.00000
#   valid auc-roc:	0.97783+/-0.00000
#   valid auc-pr:		0.97724+/-0.00000
# Epoch 83 out of 100
# [==============================] 100.0% -- elapsed time=1.10s -- loss=0.20561 -- acc=91.809531%
#
#   valid loss:		0.19049
#   valid accuracy:	0.92133+/-0.00000
#   valid auc-roc:	0.97820+/-0.00000
#   valid auc-pr:		0.97779+/-0.00000
# Epoch 84 out of 100
# [==============================] 100.0% -- elapsed time=1.11s -- loss=0.20245 -- acc=92.033343%
#
#   valid loss:		0.19224
#   valid accuracy:	0.91867+/-0.00000
#   valid auc-roc:	0.97762+/-0.00000
#   valid auc-pr:		0.97737+/-0.00000
# Epoch 85 out of 100
# [==============================] 100.0% -- elapsed time=1.10s -- loss=0.20085 -- acc=92.104760%
#
#   valid loss:		0.19379
#   valid accuracy:	0.91967+/-0.00000
#   valid auc-roc:	0.97730+/-0.00000
#   valid auc-pr:		0.97723+/-0.00000
# Epoch 86 out of 100
# [==============================] 100.0% -- elapsed time=1.07s -- loss=0.19699 -- acc=92.347625%
#
#   valid loss:		0.18800
#   valid accuracy:	0.92067+/-0.00000
#   valid auc-roc:	0.97867+/-0.00000
#   valid auc-pr:		0.97863+/-0.00000
# Epoch 87 out of 100
# [==============================] 100.0% -- elapsed time=1.10s -- loss=0.20486 -- acc=91.780958%
#
#   valid loss:		0.18858
#   valid accuracy:	0.92067+/-0.00000
#   valid auc-roc:	0.97895+/-0.00000
#   valid auc-pr:		0.97886+/-0.00000
# Epoch 88 out of 100
# [==============================] 100.0% -- elapsed time=1.09s -- loss=0.20450 -- acc=91.928573%
#
#   valid loss:		0.18967
#   valid accuracy:	0.92133+/-0.00000
#   valid auc-roc:	0.97826+/-0.00000
#   valid auc-pr:		0.97798+/-0.00000
# Epoch 89 out of 100
# [==============================] 100.0% -- elapsed time=1.10s -- loss=0.20135 -- acc=91.919052%
#
#   valid loss:		0.19758
#   valid accuracy:	0.91700+/-0.00000
#   valid auc-roc:	0.97779+/-0.00000
#   valid auc-pr:		0.97758+/-0.00000
# Epoch 90 out of 100
# [==============================] 100.0% -- elapsed time=1.06s -- loss=0.20433 -- acc=91.857156%
#
#   valid loss:		0.18913
#   valid accuracy:	0.92100+/-0.00000
#   valid auc-roc:	0.97890+/-0.00000
#   valid auc-pr:		0.97900+/-0.00000
# Epoch 91 out of 100
# [==============================] 100.0% -- elapsed time=1.11s -- loss=0.19649 -- acc=92.023812%
#
#   valid loss:		0.19118
#   valid accuracy:	0.91900+/-0.00000
#   valid auc-roc:	0.97781+/-0.00000
#   valid auc-pr:		0.97773+/-0.00000
# Epoch 92 out of 100
# [==============================] 100.0% -- elapsed time=1.12s -- loss=0.19716 -- acc=92.219052%
#
#   valid loss:		0.19171
#   valid accuracy:	0.92300+/-0.00000
#   valid auc-roc:	0.97789+/-0.00000
#   valid auc-pr:		0.97811+/-0.00000
# Epoch 93 out of 100
# [==============================] 100.0% -- elapsed time=1.11s -- loss=0.19843 -- acc=92.209531%
#
#   valid loss:		0.19267
#   valid accuracy:	0.91533+/-0.00000
#   valid auc-roc:	0.97755+/-0.00000
#   valid auc-pr:		0.97743+/-0.00000
# Epoch 94 out of 100
# [==============================] 100.0% -- elapsed time=1.10s -- loss=0.20470 -- acc=91.742864%
#
#   valid loss:		0.19491
#   valid accuracy:	0.92033+/-0.00000
#   valid auc-roc:	0.97730+/-0.00000
#   valid auc-pr:		0.97715+/-0.00000
# Epoch 95 out of 100
# [==============================] 100.0% -- elapsed time=1.08s -- loss=0.19779 -- acc=92.080968%
#
#   valid loss:		0.19503
#   valid accuracy:	0.91500+/-0.00000
#   valid auc-roc:	0.97776+/-0.00000
#   valid auc-pr:		0.97768+/-0.00000
# Epoch 96 out of 100
# [==============================] 100.0% -- elapsed time=1.08s -- loss=0.19837 -- acc=91.985729%
#
#   valid loss:		0.19402
#   valid accuracy:	0.91967+/-0.00000
#   valid auc-roc:	0.97728+/-0.00000
#   valid auc-pr:		0.97682+/-0.00000
# Epoch 97 out of 100
# [==============================] 100.0% -- elapsed time=1.07s -- loss=0.19734 -- acc=92.266677%
#
#   valid loss:		0.18980
#   valid accuracy:	0.92267+/-0.00000
#   valid auc-roc:	0.97824+/-0.00000
#   valid auc-pr:		0.97791+/-0.00000
# Epoch 98 out of 100
# [==============================] 100.0% -- elapsed time=1.07s -- loss=0.19870 -- acc=92.166677%
#
#   valid loss:		0.19692
#   valid accuracy:	0.91700+/-0.00000
#   valid auc-roc:	0.97708+/-0.00000
#   valid auc-pr:		0.97699+/-0.00000
# Epoch 99 out of 100
# [==============================] 100.0% -- elapsed time=1.08s -- loss=0.20080 -- acc=92.204760%
#
#   valid loss:		0.19333
#   valid accuracy:	0.92167+/-0.00000
#   valid auc-roc:	0.97797+/-0.00000
#   valid auc-pr:		0.97770+/-0.00000
# Epoch 100 out of 100
# [==============================] 100.0% -- elapsed time=1.09s -- loss=0.19893 -- acc=91.885729%
#
#   valid loss:		0.18903
#   valid accuracy:	0.92167+/-0.00000
#   valid auc-roc:	0.97843+/-0.00000
#   valid auc-pr:		0.97818+/-0.00000

# %% [markdown]
# ### Test the model

# %%
# set best parameters
nntrainer.set_best_parameters(sess)

# test model
loss, mean_vals, std_vals = nntrainer.test_model(sess, train, name='test')
# Out:
# loading model from:  ../results/model_params/LocalNet/LocalNet_do_l2_bnseed247_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/LocalNet/LocalNet_do_l2_bnseed247_best.ckpt
#   test  loss:		0.11910
#   test  accuracy:	0.96424+/-0.00000
#   test  auc-roc:	0.99375+/-0.00000
#   test  auc-pr:		0.99321+/-0.00000

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os, sys
import numpy as np
import helper
import tensorflow as tf
from deepomics import neuralnetwork as nn
from deepomics import utils, fit, visualize, saliency, metrics
import helper
sys.path.append('../..')
import mutagenesisfunctions as mf

#-----------------------------------------------------------------------------------------------

def fom_heatmap(X, layer, alphabet, nntrainer, sess, eps=1e-7):
    
    def mutate(sequence, seq_length, dims):
        num_mutations = seq_length * dims
        hotplot_mutations = np.zeros((num_mutations,seq_length,1,dims)) 

        for position in range(seq_length):
            for nuc in range(dims):
                mut_seq = np.copy(sequence)          
                mut_seq[0, position, 0, :] = np.zeros(dims)
                mut_seq[0, position, 0, nuc] = 1.0

                hotplot_mutations[(position*dims)+nuc] = mut_seq
        return hotplot_mutations

    #first mutate the sequence
    X_mut = mutate(X, X.shape[1], X.shape[3])

    #take all the mutations and assign them into a dict for deepomics
    mutations = {'inputs': X_mut, 'targets': np.ones((X_mut.shape[0], 1))}
    #Get output or logits activations for the mutations
    mut_predictions = nntrainer.get_activations(sess, mutations, layer=layer)

    #take the WT and put it into a dict for deepomics
    WT = {'inputs': X, 'targets': np.ones((X.shape[0], 1))}
    #Get output or logits activations for the WT sequence
    predictions = nntrainer.get_activations(sess, WT, layer=layer)

    #shape the predictions of the mutations into the shape of a heatmap
    heat_mut = mut_predictions.reshape(X.shape[1],4).T
    
    #normalize the heat map rearrangement by minusing it by the true prediction score of that test sequence
    #norm_heat_mut = heat_mut - predictions[0] + eps
    #norm_heat_mut = utils.normalize_pwm(norm_heat_mut, factor=4)

    return (heat_mut)
#-----------------------------------------------------------------------------------------------

'''
This script outputs the First Order Mutagenesis scores for every model and every regularization mode over every positively labelled sequence.
It outputs a single np.array with the shape (num_models, num_reg, num_pos, dims, seqlen)

It will also output an array in the shape (num_models, num_reg) showing the name of each model for ease of indexing into the larger model.

'''
#------------------------------------------------------------------------------------------------

all_models = ['DistNet', 'LocalNet', 'DeepBind', 'StandardNet']
num_models = len(all_models) # number of models
dropout_status = [True, True, 	False, 	False, 	False, True,  True,  False]
l2_status = 	 [True, False, 	True, 	False, 	False, True,  False, True]
bn_status = 	 [True, False, 	False, 	True, 	False, False, True,  True]
num_reg = len(dropout_status) # number of regularization types

# save path
results_path = '../results'
params_path = utils.make_directory(results_path, 'model_params')

# dataset path
data_path = '../data/Synthetic_dataset.h5'

# load dataset
train, valid, test = helper.load_synthetic_dataset(data_path)
#Get the indices of correctly labelled sequences
right_index = np.where(test['targets'][:,0]==1)[0]
num_pos = len(right_index) # number of positively labelled sequences

# get data shapes
input_shape = list(train['inputs'].shape)
input_shape[0] = None

_, seqlen, _, dims = test['inputs'].shape # the length of each sequence and the number of dimensions

#initialize an array to hold the FoM results
full_fom_predictions = np.zeros((num_models, num_reg, num_pos, dims, seqlen))

# loop through models
for m, model_name in enumerate(all_models):

    #loop through every regularization type
    for r in range(len(dropout_status)):
        tf.reset_default_graph()
        print('model: ' + model_name)

        # compile neural trainer
        name = model_name
        if dropout_status[i]:
            name += '_do'
        if l2_status[i]:
            name += '_l2'
        if bn_status[i]:
            name += '_bn'
        model_path = utils.make_directory(params_path, model_name)
        file_path = os.path.join(model_path, name)

        # load model parameters
        model_layers, optimization, _ = helper.load_model(model_name, 
                                                          input_shape,
                                                          dropout_status[i], 
                                                          l2_status[i], 
                                                          bn_status[i])
        # build neural network class
        nnmodel = nn.NeuralNet(seed=247)
        nnmodel.build_layers(model_layers, optimization, supervised=True)

        # compile neural trainers
        nntrainer = nn.NeuralTrainer(nnmodel, save='best', file_path=file_path)

        # initialize session
        sess = utils.initialize_session()

        # load best parameters
        nntrainer.set_best_parameters(sess)
        
        for p, index in enumerate(right_index):
            #Extract a sequence and perform First Order Mutagenesis
            X = np.expand_dims(test['inputs'][index], axis=0)
            
            full_fom_predictions[m, r, p, :, :] = fom_heatmap(X, 'output', 'dna', nntrainer, sess)
# Out:
# loading training data
# loading cross-validation data
# loading test data
# model: DistNet
# loading model from:  ../results/model_params/DistNet/DistNet_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/DistNet/DistNet_l2_bn_best.ckpt
# model: DistNet
# loading model from:  ../results/model_params/DistNet/DistNet_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/DistNet/DistNet_l2_bn_best.ckpt
# model: DistNet
# loading model from:  ../results/model_params/DistNet/DistNet_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/DistNet/DistNet_l2_bn_best.ckpt
# model: DistNet
# loading model from:  ../results/model_params/DistNet/DistNet_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/DistNet/DistNet_l2_bn_best.ckpt
# model: DistNet
# loading model from:  ../results/model_params/DistNet/DistNet_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/DistNet/DistNet_l2_bn_best.ckpt
# model: DistNet
# loading model from:  ../results/model_params/DistNet/DistNet_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/DistNet/DistNet_l2_bn_best.ckpt
# model: DistNet
# loading model from:  ../results/model_params/DistNet/DistNet_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/DistNet/DistNet_l2_bn_best.ckpt
# model: DistNet
# loading model from:  ../results/model_params/DistNet/DistNet_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/DistNet/DistNet_l2_bn_best.ckpt
# model: LocalNet
# loading model from:  ../results/model_params/LocalNet/LocalNet_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/LocalNet/LocalNet_l2_bn_best.ckpt
# model: LocalNet
# loading model from:  ../results/model_params/LocalNet/LocalNet_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/LocalNet/LocalNet_l2_bn_best.ckpt
# model: LocalNet
# loading model from:  ../results/model_params/LocalNet/LocalNet_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/LocalNet/LocalNet_l2_bn_best.ckpt
# model: LocalNet
# loading model from:  ../results/model_params/LocalNet/LocalNet_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/LocalNet/LocalNet_l2_bn_best.ckpt
# model: LocalNet
# loading model from:  ../results/model_params/LocalNet/LocalNet_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/LocalNet/LocalNet_l2_bn_best.ckpt
# model: LocalNet
# loading model from:  ../results/model_params/LocalNet/LocalNet_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/LocalNet/LocalNet_l2_bn_best.ckpt
# model: LocalNet
# loading model from:  ../results/model_params/LocalNet/LocalNet_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/LocalNet/LocalNet_l2_bn_best.ckpt
# model: LocalNet
# loading model from:  ../results/model_params/LocalNet/LocalNet_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/LocalNet/LocalNet_l2_bn_best.ckpt
# model: DeepBind
# loading model from:  ../results/model_params/DeepBind/DeepBind_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/DeepBind/DeepBind_l2_bn_best.ckpt
# model: DeepBind
# loading model from:  ../results/model_params/DeepBind/DeepBind_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/DeepBind/DeepBind_l2_bn_best.ckpt
# model: DeepBind
# loading model from:  ../results/model_params/DeepBind/DeepBind_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/DeepBind/DeepBind_l2_bn_best.ckpt
# model: DeepBind
# loading model from:  ../results/model_params/DeepBind/DeepBind_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/DeepBind/DeepBind_l2_bn_best.ckpt
# model: DeepBind
# loading model from:  ../results/model_params/DeepBind/DeepBind_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/DeepBind/DeepBind_l2_bn_best.ckpt
# model: DeepBind
# loading model from:  ../results/model_params/DeepBind/DeepBind_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/DeepBind/DeepBind_l2_bn_best.ckpt
# model: DeepBind
# loading model from:  ../results/model_params/DeepBind/DeepBind_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/DeepBind/DeepBind_l2_bn_best.ckpt
# model: DeepBind
# loading model from:  ../results/model_params/DeepBind/DeepBind_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/DeepBind/DeepBind_l2_bn_best.ckpt
# model: StandardNet
# loading model from:  ../results/model_params/StandardNet/StandardNet_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/StandardNet/StandardNet_l2_bn_best.ckpt
# model: StandardNet
# loading model from:  ../results/model_params/StandardNet/StandardNet_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/StandardNet/StandardNet_l2_bn_best.ckpt
# model: StandardNet
# loading model from:  ../results/model_params/StandardNet/StandardNet_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/StandardNet/StandardNet_l2_bn_best.ckpt
# model: StandardNet
# loading model from:  ../results/model_params/StandardNet/StandardNet_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/StandardNet/StandardNet_l2_bn_best.ckpt
# model: StandardNet
# loading model from:  ../results/model_params/StandardNet/StandardNet_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/StandardNet/StandardNet_l2_bn_best.ckpt
# model: StandardNet
# loading model from:  ../results/model_params/StandardNet/StandardNet_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/StandardNet/StandardNet_l2_bn_best.ckpt
# model: StandardNet
# loading model from:  ../results/model_params/StandardNet/StandardNet_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/StandardNet/StandardNet_l2_bn_best.ckpt
# model: StandardNet
# loading model from:  ../results/model_params/StandardNet/StandardNet_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/StandardNet/StandardNet_l2_bn_best.ckpt

# %%
import h5py

#save the array
save_path = utils.make_directory(results_path, 'FoM_full_analysis')
hdf5path = os.path.join(save_path, 'full_fom_predictions'+'.hdf5')
with h5py.File(hdf5path, 'w') as f:
    f.create_dataset('full_fom', data=full_fom_predictions.astype(np.float32), compression='gzip')
# Out:
# making directory: ../results/FoM_full_analysis

# %%
data_path = hdf5path
with h5py.File(data_path, 'r') as dataset:
    full_fom = np.array(dataset['full_fom'])

# %%
full_fom.shape
# Out:
# (4, 8, 2972, 4, 200)
