# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os, sys
import numpy as np
import helper
import tensorflow as tf
from deepomics import neuralnetwork as nn
from deepomics import utils, fit


all_models = ['DistNet', 'LocalNet', 'DeepBind', 'StandardNet']
num_models = len(all_models)
dropout_status = [True, True, 	False, 	False, 	False, True,  True,  False]
l2_status = 	 [True, False, 	True, 	False, 	False, True,  False, True]
bn_status = 	 [True, False, 	False, 	True, 	False, False, True,  True]
num_reg = len(dropout_status)

Names = []
# loop through models
for t, model_name in enumerate(all_models): 
    #Names[t] = []
    #loop through every regularization type
    modelsreg = []
    for i in range(len(dropout_status)):

        # compile neural trainer
        name = model_name
        if dropout_status[i]:
            name += '_do'
        if l2_status[i]:
            name += '_l2'
        if bn_status[i]:
            name += '_bn'
        modelsreg.append(name)
        #Names[t].append(name)
    Names.append(modelsreg)

# %%
import pandas as pd
pd.DataFrame(Names)
# Out:
#                       0               1               2               3  \
# 0      DistNet_do_l2_bn      DistNet_do      DistNet_l2      DistNet_bn
# 1     LocalNet_do_l2_bn     LocalNet_do     LocalNet_l2     LocalNet_bn
# 2     DeepBind_do_l2_bn     DeepBind_do     DeepBind_l2     DeepBind_bn
# 3  StandardNet_do_l2_bn  StandardNet_do  StandardNet_l2  StandardNet_bn
#
#              4                  5                  6                  7
# 0      DistNet      DistNet_do_l2      DistNet_do_bn      DistNet_l2_bn
# 1     LocalNet     LocalNet_do_l2     LocalNet_do_bn     LocalNet_l2_bn
# 2     DeepBind     DeepBind_do_l2     DeepBind_do_bn     DeepBind_l2_bn
# 3  StandardNet  StandardNet_do_l2  StandardNet_do_bn  StandardNet_l2_bn

# %%
analysis_idx = {}
for m, model in enumerate(Names):
    for r, reg in enumerate(model):
        analysis_idx[reg] = [m,r]

# %%
analysis_idx
# Out:
# {'DeepBind': [2, 4],
#  'DeepBind_bn': [2, 3],
#  'DeepBind_do': [2, 1],
#  'DeepBind_do_bn': [2, 6],
#  'DeepBind_do_l2': [2, 5],
#  'DeepBind_do_l2_bn': [2, 0],
#  'DeepBind_l2': [2, 2],
#  'DeepBind_l2_bn': [2, 7],
#  'DistNet': [0, 4],
#  'DistNet_bn': [0, 3],
#  'DistNet_do': [0, 1],
#  'DistNet_do_bn': [0, 6],
#  'DistNet_do_l2': [0, 5],
#  'DistNet_do_l2_bn': [0, 0],
#  'DistNet_l2': [0, 2],
#  'DistNet_l2_bn': [0, 7],
#  'LocalNet': [1, 4],
#  'LocalNet_bn': [1, 3],
#  'LocalNet_do': [1, 1],
#  'LocalNet_do_bn': [1, 6],
#  'LocalNet_do_l2': [1, 5],
#  'LocalNet_do_l2_bn': [1, 0],
#  'LocalNet_l2': [1, 2],
#  'LocalNet_l2_bn': [1, 7],
#  'StandardNet': [3, 4],
#  'StandardNet_bn': [3, 3],
#  'StandardNet_do': [3, 1],
#  'StandardNet_do_bn': [3, 6],
#  'StandardNet_do_l2': [3, 5],
#  'StandardNet_do_l2_bn': [3, 0],
#  'StandardNet_l2': [3, 2],
#  'StandardNet_l2_bn': [3, 7]}

# %%
# save path
results_path = '../results'
params_path = utils.make_directory(results_path, 'model_params')

# dataset path
data_path = '../data/Synthetic_dataset.h5'

# load dataset
train, valid, test = helper.load_synthetic_dataset(data_path)
#Get the indices of correctly labelled sequences
right_index = np.where(train['targets'][:,0]==1)[0]
num_pos = len(right_index)
# Out:
# loading training data
# loading cross-validation data
# loading test data

# %%
np.zeros((2,4))
# Out:
# array([[0., 0., 0., 0.],
#        [0., 0., 0., 0.]])

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os, sys
import numpy as np
import helper
import tensorflow as tf
from deepomics import neuralnetwork as nn
from deepomics import utils, fit

#------------------------------------------------------------------------------------------------

all_models = ['DistNet', 'LocalNet', 'DeepBind', 'StandardNet']
dropout_status = [True, True, 	False, 	False, 	False, True,  True,  False]
l2_status = 	 [True, False, 	True, 	False, 	False, True,  False, True]
bn_status = 	 [True, False, 	False, 	True, 	False, False, True,  True]

# save path
results_path = '../results'
params_path = utils.make_directory(results_path, 'model_params')

# dataset path
data_path = '../data/Synthetic_dataset.h5'

# load dataset
train, valid, test = helper.load_synthetic_dataset(data_path)

# get data shapes
input_shape = list(train['inputs'].shape)
input_shape[0] = None


for i in range(len(dropout_status)):

	# loop through models
	for model_name in all_models:
		tf.reset_default_graph()
		print('model: ' + model_name)

		# compile neural trainer
		name = model_name
		if dropout_status[i]:
			name += '_do'
		if l2_status[i]:
			name += '_l2'
		if bn_status[i]:
			name += '_bn'
		model_path = utils.make_directory(params_path, model_name)
		file_path = os.path.join(model_path, name)

		# load model parameters
		model_layers, optimization, _ = helper.load_model(model_name, 
														  input_shape,
														  dropout_status[i], 
														  l2_status[i], 
														  bn_status[i])

		# build neural network class
		nnmodel = nn.NeuralNet(seed=247)
		nnmodel.build_layers(model_layers, optimization, supervised=True)

		nntrainer = nn.NeuralTrainer(nnmodel, save='best', file_path=file_path)

		# initialize session
		sess = utils.initialize_session()

		# set data in dictionary
		data = {'train': train, 'valid': valid, 'test': test}
		fit.train_minibatch(sess, nntrainer, data, batch_size=100, num_epochs=100, 
							patience=100, verbose=2, shuffle=True, save_all=False)
# Out:
# loading training data
# loading cross-validation data
# loading test data
# model: DistNet
# Epoch 1 out of 100
# [==============================] 100.0% -- elapsed time=2.57s -- loss=0.81664 -- acc=50.185719%
#
#   valid loss:		0.71985
#   valid accuracy:	0.50133+/-0.00000
#   valid auc-roc:	0.50517+/-0.00000
#   valid auc-pr:		0.50299+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/model_params/DistNet/DistNet_do_l2_bn_best.ckpt
# Epoch 2 out of 100
# [==============================] 100.0% -- elapsed time=2.08s -- loss=0.73804 -- acc=49.742864%
#
#   valid loss:		0.69978
#   valid accuracy:	0.50200+/-0.00000
#   valid auc-roc:	0.49576+/-0.00000
#   valid auc-pr:		0.49182+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/model_params/DistNet/DistNet_do_l2_bn_best.ckpt
# Epoch 3 out of 100
# [==============================] 100.0% -- elapsed time=2.10s -- loss=0.70779 -- acc=49.914281%
#
#   valid loss:		0.69660
#   valid accuracy:	0.50300+/-0.00000
#   valid auc-roc:	0.50205+/-0.00000
#   valid auc-pr:		0.49346+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/model_params/DistNet/DistNet_do_l2_bn_best.ckpt
# Epoch 4 out of 100
# [==============================] 100.0% -- elapsed time=2.12s -- loss=0.70059 -- acc=50.295240%
#
#   valid loss:		0.69672
#   valid accuracy:	0.50267+/-0.00000
#   valid auc-roc:	0.49162+/-0.00000
#   valid auc-pr:		0.48248+/-0.00000
# Epoch 5 out of 100
# [==============================] 100.0% -- elapsed time=2.11s -- loss=0.69707 -- acc=50.095240%
#
#   valid loss:		0.69676
#   valid accuracy:	0.50267+/-0.00000
#   valid auc-roc:	0.50621+/-0.00000
#   valid auc-pr:		0.49470+/-0.00000
# Epoch 6 out of 100
# [==============================] 100.0% -- elapsed time=2.13s -- loss=0.69626 -- acc=49.704760%
#
#   valid loss:		0.69636
#   valid accuracy:	0.50267+/-0.00000
#   valid auc-roc:	0.48726+/-0.00000
#   valid auc-pr:		0.47883+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/model_params/DistNet/DistNet_do_l2_bn_best.ckpt
# Epoch 7 out of 100
# [==============================] 100.0% -- elapsed time=2.20s -- loss=0.69575 -- acc=49.985719%
#
#   valid loss:		0.69647
#   valid accuracy:	0.50267+/-0.00000
#   valid auc-roc:	0.49111+/-0.00000
#   valid auc-pr:		0.48925+/-0.00000
# Epoch 8 out of 100
# [==============================] 100.0% -- elapsed time=2.16s -- loss=0.69539 -- acc=50.166667%
#
#   valid loss:		0.69502
#   valid accuracy:	0.50267+/-0.00000
#   valid auc-roc:	0.48713+/-0.00000
#   valid auc-pr:		0.48229+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/model_params/DistNet/DistNet_do_l2_bn_best.ckpt
# Epoch 9 out of 100
# [==============================] 100.0% -- elapsed time=2.21s -- loss=0.69528 -- acc=49.747625%
#
#   valid loss:		0.69523
#   valid accuracy:	0.50267+/-0.00000
#   valid auc-roc:	0.47997+/-0.00000
#   valid auc-pr:		0.47972+/-0.00000
# Epoch 10 out of 100
# [==============================] 100.0% -- elapsed time=2.16s -- loss=0.69525 -- acc=49.871437%
#
#   valid loss:		0.69567
#   valid accuracy:	0.50267+/-0.00000
#   valid auc-roc:	0.49495+/-0.00000
#   valid auc-pr:		0.49552+/-0.00000
# Epoch 11 out of 100
# [==============================] 100.0% -- elapsed time=2.15s -- loss=0.69499 -- acc=50.233333%
#
#   valid loss:		0.69574
#   valid accuracy:	0.50267+/-0.00000
#   valid auc-roc:	0.50135+/-0.00000
#   valid auc-pr:		0.50747+/-0.00000
# Epoch 12 out of 100
# [==============================] 100.0% -- elapsed time=2.15s -- loss=0.69500 -- acc=50.152385%
#
#   valid loss:		0.69544
#   valid accuracy:	0.50267+/-0.00000
#   valid auc-roc:	0.51766+/-0.00000
#   valid auc-pr:		0.51633+/-0.00000
# Epoch 13 out of 100
# [==============================] 100.0% -- elapsed time=2.17s -- loss=0.69499 -- acc=49.933333%
#
#   valid loss:		0.69420
#   valid accuracy:	0.50100+/-0.00000
#   valid auc-roc:	0.50603+/-0.00000
#   valid auc-pr:		0.50051+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/model_params/DistNet/DistNet_do_l2_bn_best.ckpt
# Epoch 14 out of 100
# [==============================] 100.0% -- elapsed time=2.13s -- loss=0.69432 -- acc=50.404760%
#
#   valid loss:		0.69511
#   valid accuracy:	0.50267+/-0.00000
#   valid auc-roc:	0.50326+/-0.00000
#   valid auc-pr:		0.50515+/-0.00000
# Epoch 15 out of 100
# [==============================] 100.0% -- elapsed time=2.10s -- loss=0.69427 -- acc=50.895240%
#
#   valid loss:		0.69638
#   valid accuracy:	0.50267+/-0.00000
#   valid auc-roc:	0.50754+/-0.00000
#   valid auc-pr:		0.50620+/-0.00000
# Epoch 16 out of 100
# [==============================] 100.0% -- elapsed time=2.13s -- loss=0.69371 -- acc=51.023812%
#
#   valid loss:		0.69671
#   valid accuracy:	0.50267+/-0.00000
#   valid auc-roc:	0.51111+/-0.00000
#   valid auc-pr:		0.51997+/-0.00000
# Epoch 17 out of 100
# [==============================] 100.0% -- elapsed time=2.10s -- loss=0.69450 -- acc=50.238094%
#
#   valid loss:		0.69558
#   valid accuracy:	0.50267+/-0.00000
#   valid auc-roc:	0.49760+/-0.00000
#   valid auc-pr:		0.50069+/-0.00000
# Epoch 18 out of 100
# [==============================] 100.0% -- elapsed time=2.11s -- loss=0.69428 -- acc=50.571437%
#
#   valid loss:		0.69707
#   valid accuracy:	0.50267+/-0.00000
#   valid auc-roc:	0.48975+/-0.00000
#   valid auc-pr:		0.49222+/-0.00000
# Epoch 19 out of 100
# [==============================] 100.0% -- elapsed time=2.12s -- loss=0.69373 -- acc=50.576198%
#
#   valid loss:		0.69475
#   valid accuracy:	0.50200+/-0.00000
#   valid auc-roc:	0.49895+/-0.00000
#   valid auc-pr:		0.49636+/-0.00000
# Epoch 20 out of 100
# [==============================] 100.0% -- elapsed time=2.15s -- loss=0.69400 -- acc=50.719052%
#
#   valid loss:		0.69471
#   valid accuracy:	0.50367+/-0.00000
#   valid auc-roc:	0.49693+/-0.00000
#   valid auc-pr:		0.49384+/-0.00000
# Epoch 21 out of 100
# [==============================] 100.0% -- elapsed time=2.11s -- loss=0.69387 -- acc=50.885719%
#
#   valid loss:		0.69462
#   valid accuracy:	0.50067+/-0.00000
#   valid auc-roc:	0.49840+/-0.00000
#   valid auc-pr:		0.49483+/-0.00000
# Epoch 22 out of 100
# [==============================] 100.0% -- elapsed time=2.17s -- loss=0.69405 -- acc=50.304760%
#
#   valid loss:		0.69497
#   valid accuracy:	0.50300+/-0.00000
#   valid auc-roc:	0.49002+/-0.00000
#   valid auc-pr:		0.49004+/-0.00000
# Epoch 23 out of 100
# [==============================] 100.0% -- elapsed time=2.14s -- loss=0.69366 -- acc=51.004760%
#
#   valid loss:		0.69518
#   valid accuracy:	0.50300+/-0.00000
#   valid auc-roc:	0.49405+/-0.00000
#   valid auc-pr:		0.49127+/-0.00000
# Epoch 24 out of 100
# [==============================] 100.0% -- elapsed time=2.13s -- loss=0.69399 -- acc=51.161906%
#
#   valid loss:		0.69629
#   valid accuracy:	0.50267+/-0.00000
#   valid auc-roc:	0.49517+/-0.00000
#   valid auc-pr:		0.50073+/-0.00000
# Epoch 25 out of 100
# [==============================] 100.0% -- elapsed time=2.12s -- loss=0.69382 -- acc=50.685719%
#
#   valid loss:		0.69539
#   valid accuracy:	0.50267+/-0.00000
#   valid auc-roc:	0.50118+/-0.00000
#   valid auc-pr:		0.49787+/-0.00000
# Epoch 26 out of 100
# [==============================] 100.0% -- elapsed time=2.12s -- loss=0.69380 -- acc=51.000000%
#
#   valid loss:		0.69524
#   valid accuracy:	0.50267+/-0.00000
#   valid auc-roc:	0.48976+/-0.00000
#   valid auc-pr:		0.49762+/-0.00000
# Epoch 27 out of 100
# [==============================] 100.0% -- elapsed time=2.12s -- loss=0.69319 -- acc=51.090479%
#
#   valid loss:		0.69600
#   valid accuracy:	0.50267+/-0.00000
#   valid auc-roc:	0.48175+/-0.00000
#   valid auc-pr:		0.48611+/-0.00000
# Epoch 28 out of 100
# [==============================] 100.0% -- elapsed time=2.10s -- loss=0.69316 -- acc=51.747625%
#
#   valid loss:		0.69554
#   valid accuracy:	0.50267+/-0.00000
#   valid auc-roc:	0.48850+/-0.00000
#   valid auc-pr:		0.48754+/-0.00000
# Epoch 29 out of 100
# [==============================] 100.0% -- elapsed time=2.10s -- loss=0.69261 -- acc=51.857146%
#
#   valid loss:		0.69524
#   valid accuracy:	0.50267+/-0.00000
#   valid auc-roc:	0.50022+/-0.00000
#   valid auc-pr:		0.49621+/-0.00000
# Epoch 30 out of 100
# [==============================] 100.0% -- elapsed time=2.12s -- loss=0.69221 -- acc=52.109521%
#
#   valid loss:		0.69573
#   valid accuracy:	0.50233+/-0.00000
#   valid auc-roc:	0.49956+/-0.00000
#   valid auc-pr:		0.49564+/-0.00000
# Epoch 31 out of 100
# [==============================] 100.0% -- elapsed time=2.12s -- loss=0.69276 -- acc=51.847625%
#
#   valid loss:		0.69615
#   valid accuracy:	0.50167+/-0.00000
#   valid auc-roc:	0.50873+/-0.00000
#   valid auc-pr:		0.50193+/-0.00000
# Epoch 32 out of 100
# [==============================] 100.0% -- elapsed time=2.11s -- loss=0.69279 -- acc=51.952385%
#
#   valid loss:		0.69607
#   valid accuracy:	0.50267+/-0.00000
#   valid auc-roc:	0.50213+/-0.00000
#   valid auc-pr:		0.48584+/-0.00000
# Epoch 33 out of 100
# [==============================] 100.0% -- elapsed time=2.13s -- loss=0.69284 -- acc=51.452385%
#
#   valid loss:		0.69616
#   valid accuracy:	0.50267+/-0.00000
#   valid auc-roc:	0.49859+/-0.00000
#   valid auc-pr:		0.49094+/-0.00000
# Epoch 34 out of 100
# [==============================] 100.0% -- elapsed time=2.11s -- loss=0.69245 -- acc=51.604760%
#
#   valid loss:		0.69752
#   valid accuracy:	0.50233+/-0.00000
#   valid auc-roc:	0.49481+/-0.00000
#   valid auc-pr:		0.49021+/-0.00000
# Epoch 35 out of 100
# [==============================] 100.0% -- elapsed time=2.11s -- loss=0.69177 -- acc=52.571437%
#
#   valid loss:		0.69658
#   valid accuracy:	0.50167+/-0.00000
#   valid auc-roc:	0.49172+/-0.00000
#   valid auc-pr:		0.48935+/-0.00000
# Epoch 36 out of 100
# [==============================] 100.0% -- elapsed time=2.12s -- loss=0.69227 -- acc=52.123812%
#
#   valid loss:		0.69771
#   valid accuracy:	0.50267+/-0.00000
#   valid auc-roc:	0.49206+/-0.00000
#   valid auc-pr:		0.48841+/-0.00000
# Epoch 37 out of 100
# [==============================] 100.0% -- elapsed time=2.14s -- loss=0.69079 -- acc=53.100000%
#
#   valid loss:		0.69938
#   valid accuracy:	0.50267+/-0.00000
#   valid auc-roc:	0.49840+/-0.00000
#   valid auc-pr:		0.49322+/-0.00000
# Epoch 38 out of 100
# [==============================] 100.0% -- elapsed time=2.12s -- loss=0.69075 -- acc=52.900000%
#
#   valid loss:		0.69885
#   valid accuracy:	0.50233+/-0.00000
#   valid auc-roc:	0.50399+/-0.00000
#   valid auc-pr:		0.49569+/-0.00000
# Epoch 39 out of 100
# [==============================] 100.0% -- elapsed time=2.14s -- loss=0.69044 -- acc=53.361906%
#
#   valid loss:		0.70014
#   valid accuracy:	0.50267+/-0.00000
#   valid auc-roc:	0.50326+/-0.00000
#   valid auc-pr:		0.49535+/-0.00000
# Epoch 40 out of 100
# [==============================] 100.0% -- elapsed time=2.11s -- loss=0.69045 -- acc=53.209521%
#
#   valid loss:		0.69736
#   valid accuracy:	0.50000+/-0.00000
#   valid auc-roc:	0.51296+/-0.00000
#   valid auc-pr:		0.50165+/-0.00000
# Epoch 41 out of 100
# [==============================] 100.0% -- elapsed time=2.11s -- loss=0.68923 -- acc=53.914281%
#
#   valid loss:		0.70068
#   valid accuracy:	0.50267+/-0.00000
#   valid auc-roc:	0.51029+/-0.00000
#   valid auc-pr:		0.50108+/-0.00000
# Epoch 42 out of 100
# [==============================] 100.0% -- elapsed time=2.11s -- loss=0.68952 -- acc=53.552385%
#
#   valid loss:		0.70025
#   valid accuracy:	0.50200+/-0.00000
#   valid auc-roc:	0.51125+/-0.00000
#   valid auc-pr:		0.49991+/-0.00000
# Epoch 43 out of 100
# [==============================] 100.0% -- elapsed time=2.13s -- loss=0.69013 -- acc=53.523812%
#
#   valid loss:		0.70279
#   valid accuracy:	0.50200+/-0.00000
#   valid auc-roc:	0.51553+/-0.00000
#   valid auc-pr:		0.50041+/-0.00000
# Epoch 44 out of 100
# [==============================] 100.0% -- elapsed time=2.11s -- loss=0.68897 -- acc=53.938094%
#
#   valid loss:		0.70798
#   valid accuracy:	0.50233+/-0.00000
#   valid auc-roc:	0.50840+/-0.00000
#   valid auc-pr:		0.50122+/-0.00000
# Epoch 45 out of 100
# [==============================] 100.0% -- elapsed time=2.10s -- loss=0.68815 -- acc=54.057146%
#
#   valid loss:		0.71526
#   valid accuracy:	0.50267+/-0.00000
#   valid auc-roc:	0.50883+/-0.00000
#   valid auc-pr:		0.50417+/-0.00000
# Epoch 46 out of 100
# [==============================] 100.0% -- elapsed time=2.10s -- loss=0.68868 -- acc=53.714281%
#
#   valid loss:		0.70315
#   valid accuracy:	0.50167+/-0.00000
#   valid auc-roc:	0.51185+/-0.00000
#   valid auc-pr:		0.50607+/-0.00000
# Epoch 47 out of 100
# [==============================] 100.0% -- elapsed time=2.14s -- loss=0.68699 -- acc=54.528573%
#
#   valid loss:		0.71913
#   valid accuracy:	0.50233+/-0.00000
#   valid auc-roc:	0.51274+/-0.00000
#   valid auc-pr:		0.50648+/-0.00000
# Epoch 48 out of 100
# [==============================] 100.0% -- elapsed time=2.11s -- loss=0.68693 -- acc=54.980958%
#
#   valid loss:		0.70793
#   valid accuracy:	0.50167+/-0.00000
#   valid auc-roc:	0.51215+/-0.00000
#   valid auc-pr:		0.50432+/-0.00000
# Epoch 49 out of 100
# [==============================] 100.0% -- elapsed time=2.10s -- loss=0.68568 -- acc=55.090479%
#
#   valid loss:		0.71453
#   valid accuracy:	0.50233+/-0.00000
#   valid auc-roc:	0.50822+/-0.00000
#   valid auc-pr:		0.50098+/-0.00000
# Epoch 50 out of 100
# [==============================] 100.0% -- elapsed time=2.13s -- loss=0.68591 -- acc=55.180958%
#
#   valid loss:		0.71730
#   valid accuracy:	0.50233+/-0.00000
#   valid auc-roc:	0.51727+/-0.00000
#   valid auc-pr:		0.50649+/-0.00000
# Epoch 51 out of 100
# [==============================] 100.0% -- elapsed time=2.13s -- loss=0.68473 -- acc=55.300000%
#
#   valid loss:		0.73014
#   valid accuracy:	0.50267+/-0.00000
#   valid auc-roc:	0.51854+/-0.00000
#   valid auc-pr:		0.50712+/-0.00000
# Epoch 52 out of 100
# [==============================] 100.0% -- elapsed time=2.13s -- loss=0.68352 -- acc=55.314281%
#
#   valid loss:		0.73562
#   valid accuracy:	0.50233+/-0.00000
#   valid auc-roc:	0.51651+/-0.00000
#   valid auc-pr:		0.50666+/-0.00000
# Epoch 53 out of 100
# [==============================] 100.0% -- elapsed time=2.12s -- loss=0.68294 -- acc=55.676198%
#
#   valid loss:		0.74147
#   valid accuracy:	0.50200+/-0.00000
#   valid auc-roc:	0.51062+/-0.00000
#   valid auc-pr:		0.50317+/-0.00000
# Epoch 54 out of 100
# [==============================] 100.0% -- elapsed time=2.11s -- loss=0.68446 -- acc=55.342854%
#
#   valid loss:		0.73456
#   valid accuracy:	0.50233+/-0.00000
#   valid auc-roc:	0.50944+/-0.00000
#   valid auc-pr:		0.50567+/-0.00000
# Epoch 55 out of 100
# [==============================] 100.0% -- elapsed time=2.10s -- loss=0.68220 -- acc=56.152385%
#
#   valid loss:		0.73410
#   valid accuracy:	0.50267+/-0.00000
#   valid auc-roc:	0.50925+/-0.00000
#   valid auc-pr:		0.50621+/-0.00000
# Epoch 56 out of 100
# [==============================] 100.0% -- elapsed time=2.11s -- loss=0.68317 -- acc=56.104760%
#
#   valid loss:		0.74098
#   valid accuracy:	0.50267+/-0.00000
#   valid auc-roc:	0.51066+/-0.00000
#   valid auc-pr:		0.50446+/-0.00000
# Epoch 57 out of 100
# [==============================] 100.0% -- elapsed time=2.12s -- loss=0.67983 -- acc=57.219052%
#
#   valid loss:		0.71268
#   valid accuracy:	0.50367+/-0.00000
#   valid auc-roc:	0.50858+/-0.00000
#   valid auc-pr:		0.50096+/-0.00000
# Epoch 58 out of 100
# [==============================] 100.0% -- elapsed time=2.12s -- loss=0.68052 -- acc=56.614281%
#
#   valid loss:		0.73173
#   valid accuracy:	0.50200+/-0.00000
#   valid auc-roc:	0.51599+/-0.00000
#   valid auc-pr:		0.50672+/-0.00000
# Epoch 59 out of 100
# [==============================] 100.0% -- elapsed time=2.14s -- loss=0.67896 -- acc=57.195240%
#
#   valid loss:		0.73139
#   valid accuracy:	0.50267+/-0.00000
#   valid auc-roc:	0.51224+/-0.00000
#   valid auc-pr:		0.50584+/-0.00000
# Epoch 60 out of 100
# [==============================] 100.0% -- elapsed time=2.41s -- loss=0.67945 -- acc=57.147625%
#
#   valid loss:		0.73823
#   valid accuracy:	0.50267+/-0.00000
#   valid auc-roc:	0.51195+/-0.00000
#   valid auc-pr:		0.50712+/-0.00000
# Epoch 61 out of 100
# [==============================] 100.0% -- elapsed time=2.01s -- loss=0.67892 -- acc=56.804760%
#
#   valid loss:		0.74235
#   valid accuracy:	0.50233+/-0.00000
#   valid auc-roc:	0.50947+/-0.00000
#   valid auc-pr:		0.50679+/-0.00000
# Epoch 62 out of 100
# [==============================] 100.0% -- elapsed time=2.63s -- loss=0.67591 -- acc=57.600000%
#
#   valid loss:		0.73131
#   valid accuracy:	0.50367+/-0.00000
#   valid auc-roc:	0.51050+/-0.00000
#   valid auc-pr:		0.50367+/-0.00000
# Epoch 63 out of 100
# [==============================] 100.0% -- elapsed time=2.39s -- loss=0.67853 -- acc=57.471437%
#
#   valid loss:		0.74658
#   valid accuracy:	0.50233+/-0.00000
#   valid auc-roc:	0.50488+/-0.00000
#   valid auc-pr:		0.50300+/-0.00000
# Epoch 64 out of 100
# [==============================] 100.0% -- elapsed time=2.17s -- loss=0.67617 -- acc=57.414281%
#
#   valid loss:		0.75564
#   valid accuracy:	0.50300+/-0.00000
#   valid auc-roc:	0.50455+/-0.00000
#   valid auc-pr:		0.50143+/-0.00000
# Epoch 65 out of 100
# [==============================] 100.0% -- elapsed time=2.03s -- loss=0.67629 -- acc=57.600000%
#
#   valid loss:		0.74937
#   valid accuracy:	0.50233+/-0.00000
#   valid auc-roc:	0.50905+/-0.00000
#   valid auc-pr:		0.50614+/-0.00000
# Epoch 66 out of 100
# [==============================] 100.0% -- elapsed time=2.03s -- loss=0.67761 -- acc=57.457146%
#
#   valid loss:		0.75509
#   valid accuracy:	0.50233+/-0.00000
#   valid auc-roc:	0.50612+/-0.00000
#   valid auc-pr:		0.50494+/-0.00000
# Epoch 67 out of 100
# [==============================] 100.0% -- elapsed time=2.01s -- loss=0.67427 -- acc=58.071437%
#
#   valid loss:		0.78221
#   valid accuracy:	0.50233+/-0.00000
#   valid auc-roc:	0.50622+/-0.00000
#   valid auc-pr:		0.50406+/-0.00000
# Epoch 68 out of 100
# [==============================] 100.0% -- elapsed time=2.02s -- loss=0.67471 -- acc=58.319052%
#
#   valid loss:		0.75743
#   valid accuracy:	0.50267+/-0.00000
#   valid auc-roc:	0.50550+/-0.00000
#   valid auc-pr:		0.50299+/-0.00000
# Epoch 69 out of 100
# [==============================] 100.0% -- elapsed time=2.04s -- loss=0.67388 -- acc=57.966667%
#
#   valid loss:		0.77262
#   valid accuracy:	0.50300+/-0.00000
#   valid auc-roc:	0.50722+/-0.00000
#   valid auc-pr:		0.50659+/-0.00000
# Epoch 70 out of 100
# [==============================] 100.0% -- elapsed time=2.02s -- loss=0.67438 -- acc=57.980958%
#
#   valid loss:		0.75243
#   valid accuracy:	0.50333+/-0.00000
#   valid auc-roc:	0.51003+/-0.00000
#   valid auc-pr:		0.51036+/-0.00000
# Epoch 71 out of 100
# [==============================] 100.0% -- elapsed time=2.04s -- loss=0.67339 -- acc=58.071437%
#
#   valid loss:		0.77291
#   valid accuracy:	0.50233+/-0.00000
#   valid auc-roc:	0.50953+/-0.00000
#   valid auc-pr:		0.51019+/-0.00000
# Epoch 72 out of 100
# [==============================] 100.0% -- elapsed time=2.01s -- loss=0.66969 -- acc=59.700000%
#
#   valid loss:		0.77084
#   valid accuracy:	0.50267+/-0.00000
#   valid auc-roc:	0.50553+/-0.00000
#   valid auc-pr:		0.50627+/-0.00000
# Epoch 73 out of 100
# [==============================] 100.0% -- elapsed time=2.01s -- loss=0.67018 -- acc=58.861906%
#
#   valid loss:		0.75890
#   valid accuracy:	0.50433+/-0.00000
#   valid auc-roc:	0.50841+/-0.00000
#   valid auc-pr:		0.50819+/-0.00000
# Epoch 74 out of 100
# [==============================] 100.0% -- elapsed time=2.02s -- loss=0.66940 -- acc=59.066667%
#
#   valid loss:		0.76963
#   valid accuracy:	0.50267+/-0.00000
#   valid auc-roc:	0.50540+/-0.00000
#   valid auc-pr:		0.50701+/-0.00000
# Epoch 75 out of 100
# [==============================] 100.0% -- elapsed time=2.03s -- loss=0.66925 -- acc=59.200000%
#
#   valid loss:		0.76807
#   valid accuracy:	0.50467+/-0.00000
#   valid auc-roc:	0.50834+/-0.00000
#   valid auc-pr:		0.50890+/-0.00000
# Epoch 76 out of 100
# [==============================] 100.0% -- elapsed time=2.04s -- loss=0.66910 -- acc=59.133333%
#
#   valid loss:		0.77720
#   valid accuracy:	0.50267+/-0.00000
#   valid auc-roc:	0.50222+/-0.00000
#   valid auc-pr:		0.50352+/-0.00000
# Epoch 77 out of 100
# [==============================] 100.0% -- elapsed time=2.02s -- loss=0.66518 -- acc=59.695240%
#
#   valid loss:		0.77321
#   valid accuracy:	0.50400+/-0.00000
#   valid auc-roc:	0.50188+/-0.00000
#   valid auc-pr:		0.50202+/-0.00000
# Epoch 78 out of 100
# [==============================] 100.0% -- elapsed time=2.02s -- loss=0.66895 -- acc=59.109521%
#
#   valid loss:		0.75412
#   valid accuracy:	0.50367+/-0.00000
#   valid auc-roc:	0.50550+/-0.00000
#   valid auc-pr:		0.50323+/-0.00000
# Epoch 79 out of 100
# [==============================] 100.0% -- elapsed time=2.02s -- loss=0.66379 -- acc=60.057146%
#
#   valid loss:		0.77985
#   valid accuracy:	0.50167+/-0.00000
#   valid auc-roc:	0.50357+/-0.00000
#   valid auc-pr:		0.50118+/-0.00000
# Epoch 80 out of 100
# [==============================] 100.0% -- elapsed time=2.02s -- loss=0.66809 -- acc=59.452385%
#
#   valid loss:		0.78465
#   valid accuracy:	0.50233+/-0.00000
#   valid auc-roc:	0.51025+/-0.00000
#   valid auc-pr:		0.50540+/-0.00000
# Epoch 81 out of 100
# [==============================] 100.0% -- elapsed time=2.04s -- loss=0.66508 -- acc=59.690479%
#
#   valid loss:		0.77914
#   valid accuracy:	0.50233+/-0.00000
#   valid auc-roc:	0.50903+/-0.00000
#   valid auc-pr:		0.50659+/-0.00000
# Epoch 82 out of 100
# [==============================] 100.0% -- elapsed time=2.02s -- loss=0.66343 -- acc=59.790479%
#
#   valid loss:		0.77489
#   valid accuracy:	0.50367+/-0.00000
#   valid auc-roc:	0.50507+/-0.00000
#   valid auc-pr:		0.50471+/-0.00000
# Epoch 83 out of 100
# [==============================] 100.0% -- elapsed time=2.00s -- loss=0.66405 -- acc=59.814281%
#
#   valid loss:		0.77474
#   valid accuracy:	0.50367+/-0.00000
#   valid auc-roc:	0.50623+/-0.00000
#   valid auc-pr:		0.50354+/-0.00000
# Epoch 84 out of 100
# [==============================] 100.0% -- elapsed time=2.04s -- loss=0.66544 -- acc=59.952385%
#
#   valid loss:		0.77771
#   valid accuracy:	0.50367+/-0.00000
#   valid auc-roc:	0.51075+/-0.00000
#   valid auc-pr:		0.50536+/-0.00000
# Epoch 85 out of 100
# [==============================] 100.0% -- elapsed time=2.00s -- loss=0.66404 -- acc=59.828573%
#
#   valid loss:		0.76490
#   valid accuracy:	0.50333+/-0.00000
#   valid auc-roc:	0.50659+/-0.00000
#   valid auc-pr:		0.50483+/-0.00000
# Epoch 86 out of 100
# [==============================] 100.0% -- elapsed time=2.02s -- loss=0.66418 -- acc=60.014281%
#
#   valid loss:		0.76108
#   valid accuracy:	0.50067+/-0.00000
#   valid auc-roc:	0.50604+/-0.00000
#   valid auc-pr:		0.50006+/-0.00000
# Epoch 87 out of 100
# [==============================] 100.0% -- elapsed time=2.02s -- loss=0.66114 -- acc=60.257146%
#
#   valid loss:		0.78437
#   valid accuracy:	0.50400+/-0.00000
#   valid auc-roc:	0.50387+/-0.00000
#   valid auc-pr:		0.50249+/-0.00000
# Epoch 88 out of 100
# [==============================] 100.0% -- elapsed time=2.01s -- loss=0.66177 -- acc=60.361906%
#
#   valid loss:		0.77333
#   valid accuracy:	0.50367+/-0.00000
#   valid auc-roc:	0.50668+/-0.00000
#   valid auc-pr:		0.50554+/-0.00000
# Epoch 89 out of 100
# [==============================] 100.0% -- elapsed time=2.03s -- loss=0.66149 -- acc=60.152385%
#
#   valid loss:		0.81329
#   valid accuracy:	0.50267+/-0.00000
#   valid auc-roc:	0.50707+/-0.00000
#   valid auc-pr:		0.50196+/-0.00000
# Epoch 90 out of 100
# [==============================] 100.0% -- elapsed time=2.02s -- loss=0.66019 -- acc=60.642854%
#
#   valid loss:		0.79030
#   valid accuracy:	0.50267+/-0.00000
#   valid auc-roc:	0.50709+/-0.00000
#   valid auc-pr:		0.50381+/-0.00000
# Epoch 91 out of 100
# [==============================] 100.0% -- elapsed time=2.01s -- loss=0.65984 -- acc=60.652385%
#
#   valid loss:		0.80266
#   valid accuracy:	0.50233+/-0.00000
#   valid auc-roc:	0.50359+/-0.00000
#   valid auc-pr:		0.50123+/-0.00000
# Epoch 92 out of 100
# [==============================] 100.0% -- elapsed time=2.02s -- loss=0.65930 -- acc=60.809521%
#
#   valid loss:		0.76366
#   valid accuracy:	0.50533+/-0.00000
#   valid auc-roc:	0.50498+/-0.00000
#   valid auc-pr:		0.50456+/-0.00000
# Epoch 93 out of 100
# [==============================] 100.0% -- elapsed time=2.02s -- loss=0.65565 -- acc=60.966667%
#
#   valid loss:		0.78688
#   valid accuracy:	0.50333+/-0.00000
#   valid auc-roc:	0.50929+/-0.00000
#   valid auc-pr:		0.50826+/-0.00000
# Epoch 94 out of 100
# [==============================] 100.0% -- elapsed time=2.02s -- loss=0.65634 -- acc=61.366667%
#
#   valid loss:		0.77742
#   valid accuracy:	0.50500+/-0.00000
#   valid auc-roc:	0.51074+/-0.00000
#   valid auc-pr:		0.51070+/-0.00000
# Epoch 95 out of 100
# [==============================] 100.0% -- elapsed time=2.04s -- loss=0.65905 -- acc=60.704760%
#
#   valid loss:		0.78039
#   valid accuracy:	0.50400+/-0.00000
#   valid auc-roc:	0.50641+/-0.00000
#   valid auc-pr:		0.50513+/-0.00000
# Epoch 96 out of 100
# [==============================] 100.0% -- elapsed time=2.01s -- loss=0.65490 -- acc=61.547625%
#
#   valid loss:		0.79054
#   valid accuracy:	0.50267+/-0.00000
#   valid auc-roc:	0.50276+/-0.00000
#   valid auc-pr:		0.50419+/-0.00000
# Epoch 97 out of 100
# [==============================] 100.0% -- elapsed time=2.01s -- loss=0.65859 -- acc=60.971437%
#
#   valid loss:		0.80982
#   valid accuracy:	0.50233+/-0.00000
#   valid auc-roc:	0.50294+/-0.00000
#   valid auc-pr:		0.50071+/-0.00000
# Epoch 98 out of 100
# [==============================] 100.0% -- elapsed time=2.03s -- loss=0.65577 -- acc=61.438094%
#
#   valid loss:		0.79989
#   valid accuracy:	0.50267+/-0.00000
#   valid auc-roc:	0.50409+/-0.00000
#   valid auc-pr:		0.49955+/-0.00000
# Epoch 99 out of 100
# [==============================] 100.0% -- elapsed time=2.01s -- loss=0.65735 -- acc=61.214281%
#
#   valid loss:		0.77927
#   valid accuracy:	0.50167+/-0.00000
#   valid auc-roc:	0.50400+/-0.00000
#   valid auc-pr:		0.50011+/-0.00000
# Epoch 100 out of 100
# [==============================] 100.0% -- elapsed time=2.02s -- loss=0.65430 -- acc=61.561906%
#
#   valid loss:		0.78274
#   valid accuracy:	0.50233+/-0.00000
#   valid auc-roc:	0.49871+/-0.00000
#   valid auc-pr:		0.49797+/-0.00000
# model: LocalNet
# Epoch 1 out of 100
# [==============================] 100.0% -- elapsed time=1.29s -- loss=0.78214 -- acc=50.071437%
#
#   valid loss:		0.70239
#   valid accuracy:	0.49667+/-0.00000
#   valid auc-roc:	0.48009+/-0.00000
#   valid auc-pr:		0.48310+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/model_params/LocalNet/LocalNet_do_l2_bn_best.ckpt
# Epoch 2 out of 100
# [==============================] 100.0% -- elapsed time=1.05s -- loss=0.72148 -- acc=50.114281%
#
#   valid loss:		0.69491
#   valid accuracy:	0.49200+/-0.00000
#   valid auc-roc:	0.49129+/-0.00000
#   valid auc-pr:		0.48817+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/model_params/LocalNet/LocalNet_do_l2_bn_best.ckpt
# Epoch 3 out of 100
# [==============================] 100.0% -- elapsed time=1.04s -- loss=0.70293 -- acc=50.757146%
#
#   valid loss:		0.69418
#   valid accuracy:	0.48967+/-0.00000
#   valid auc-roc:	0.48728+/-0.00000
#   valid auc-pr:		0.48315+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/model_params/LocalNet/LocalNet_do_l2_bn_best.ckpt
# Epoch 4 out of 100
# [==============================] 100.0% -- elapsed time=1.05s -- loss=0.69747 -- acc=50.080958%
#
#   valid loss:		0.69440
#   valid accuracy:	0.49433+/-0.00000
#   valid auc-roc:	0.47492+/-0.00000
#   valid auc-pr:		0.47943+/-0.00000
# Epoch 5 out of 100
# [==============================] 100.0% -- elapsed time=1.04s -- loss=0.69543 -- acc=50.042864%
#
#   valid loss:		0.69427
#   valid accuracy:	0.50200+/-0.00000
#   valid auc-roc:	0.47722+/-0.00000
#   valid auc-pr:		0.48489+/-0.00000
# Epoch 6 out of 100
# [==============================] 100.0% -- elapsed time=1.03s -- loss=0.69443 -- acc=50.566667%
#
#   valid loss:		0.69415
#   valid accuracy:	0.50367+/-0.00000
#   valid auc-roc:	0.48060+/-0.00000
#   valid auc-pr:		0.48894+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/model_params/LocalNet/LocalNet_do_l2_bn_best.ckpt
# Epoch 7 out of 100
# [==============================] 100.0% -- elapsed time=1.04s -- loss=0.69353 -- acc=50.880958%
#
#   valid loss:		0.69360
#   valid accuracy:	0.50367+/-0.00000
#   valid auc-roc:	0.49302+/-0.00000
#   valid auc-pr:		0.49799+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/model_params/LocalNet/LocalNet_do_l2_bn_best.ckpt
# Epoch 8 out of 100
# [==============================] 100.0% -- elapsed time=1.03s -- loss=0.69313 -- acc=51.176198%
#
#   valid loss:		0.69415
#   valid accuracy:	0.50200+/-0.00000
#   valid auc-roc:	0.48838+/-0.00000
#   valid auc-pr:		0.48833+/-0.00000
# Epoch 9 out of 100
# [==============================] 100.0% -- elapsed time=1.05s -- loss=0.69433 -- acc=50.552385%
#
#   valid loss:		0.69393
#   valid accuracy:	0.50233+/-0.00000
#   valid auc-roc:	0.48003+/-0.00000
#   valid auc-pr:		0.48528+/-0.00000
# Epoch 10 out of 100
# [==============================] 100.0% -- elapsed time=1.06s -- loss=0.69356 -- acc=50.966667%
#
#   valid loss:		0.69414
#   valid accuracy:	0.49867+/-0.00000
#   valid auc-roc:	0.47667+/-0.00000
#   valid auc-pr:		0.48322+/-0.00000
# Epoch 11 out of 100
# [==============================] 100.0% -- elapsed time=1.04s -- loss=0.69311 -- acc=51.028573%
#
#   valid loss:		0.69377
#   valid accuracy:	0.50067+/-0.00000
#   valid auc-roc:	0.48509+/-0.00000
#   valid auc-pr:		0.48702+/-0.00000
# Epoch 12 out of 100
# [==============================] 100.0% -- elapsed time=1.05s -- loss=0.69304 -- acc=51.133333%
#
#   valid loss:		0.69378
#   valid accuracy:	0.49633+/-0.00000
#   valid auc-roc:	0.48944+/-0.00000
#   valid auc-pr:		0.48647+/-0.00000
# Epoch 13 out of 100
# [==============================] 100.0% -- elapsed time=1.04s -- loss=0.69292 -- acc=51.066667%
#
#   valid loss:		0.69448
#   valid accuracy:	0.50200+/-0.00000
#   valid auc-roc:	0.48602+/-0.00000
#   valid auc-pr:		0.48470+/-0.00000
# Epoch 14 out of 100
# [==============================] 100.0% -- elapsed time=1.04s -- loss=0.69293 -- acc=51.395240%
#
#   valid loss:		0.69432
#   valid accuracy:	0.49967+/-0.00000
#   valid auc-roc:	0.48450+/-0.00000
#   valid auc-pr:		0.48252+/-0.00000
# Epoch 15 out of 100
# [==============================] 100.0% -- elapsed time=1.05s -- loss=0.69312 -- acc=51.423812%
#
#   valid loss:		0.69402
#   valid accuracy:	0.49767+/-0.00000
#   valid auc-roc:	0.48582+/-0.00000
#   valid auc-pr:		0.48444+/-0.00000
# Epoch 16 out of 100
# [==============================] 100.0% -- elapsed time=1.04s -- loss=0.69155 -- acc=52.776198%
#
#   valid loss:		0.69398
#   valid accuracy:	0.49167+/-0.00000
#   valid auc-roc:	0.49738+/-0.00000
#   valid auc-pr:		0.48942+/-0.00000
# Epoch 17 out of 100
# [==============================] 100.0% -- elapsed time=1.04s -- loss=0.69191 -- acc=51.733333%
#
#   valid loss:		0.69372
#   valid accuracy:	0.49167+/-0.00000
#   valid auc-roc:	0.49865+/-0.00000
#   valid auc-pr:		0.49117+/-0.00000
# Epoch 18 out of 100
# [==============================] 100.0% -- elapsed time=1.04s -- loss=0.69222 -- acc=51.819052%
#
#   valid loss:		0.69384
#   valid accuracy:	0.50567+/-0.00000
#   valid auc-roc:	0.49974+/-0.00000
#   valid auc-pr:		0.49516+/-0.00000
# Epoch 19 out of 100
# [==============================] 100.0% -- elapsed time=1.03s -- loss=0.69141 -- acc=52.771437%
#
#   valid loss:		0.69383
#   valid accuracy:	0.49567+/-0.00000
#   valid auc-roc:	0.49647+/-0.00000
#   valid auc-pr:		0.49026+/-0.00000
# Epoch 20 out of 100
# [==============================] 100.0% -- elapsed time=1.05s -- loss=0.69057 -- acc=52.657146%
#
#   valid loss:		0.69395
#   valid accuracy:	0.49767+/-0.00000
#   valid auc-roc:	0.50209+/-0.00000
#   valid auc-pr:		0.49313+/-0.00000
# Epoch 21 out of 100
# [==============================] 100.0% -- elapsed time=1.05s -- loss=0.69119 -- acc=52.776198%
#
#   valid loss:		0.69393
#   valid accuracy:	0.49433+/-0.00000
#   valid auc-roc:	0.50325+/-0.00000
#   valid auc-pr:		0.49207+/-0.00000
# Epoch 22 out of 100
# [==============================] 100.0% -- elapsed time=1.03s -- loss=0.69015 -- acc=53.252385%
#
#   valid loss:		0.69421
#   valid accuracy:	0.49633+/-0.00000
#   valid auc-roc:	0.50267+/-0.00000
#   valid auc-pr:		0.49360+/-0.00000
# Epoch 23 out of 100
# [==============================] 100.0% -- elapsed time=1.03s -- loss=0.69124 -- acc=52.661906%
#
#   valid loss:		0.69297
#   valid accuracy:	0.50633+/-0.00000
#   valid auc-roc:	0.51372+/-0.00000
#   valid auc-pr:		0.50484+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/model_params/LocalNet/LocalNet_do_l2_bn_best.ckpt
# Epoch 24 out of 100
# [==============================] 100.0% -- elapsed time=1.04s -- loss=0.69008 -- acc=52.933333%
#
#   valid loss:		0.69364
#   valid accuracy:	0.50567+/-0.00000
#   valid auc-roc:	0.50746+/-0.00000
#   valid auc-pr:		0.49923+/-0.00000
# Epoch 25 out of 100
# [==============================] 100.0% -- elapsed time=1.06s -- loss=0.68904 -- acc=53.504760%
#
#   valid loss:		0.69385
#   valid accuracy:	0.49433+/-0.00000
#   valid auc-roc:	0.50658+/-0.00000
#   valid auc-pr:		0.49816+/-0.00000
# Epoch 26 out of 100
# [==============================] 100.0% -- elapsed time=1.05s -- loss=0.68895 -- acc=53.295240%
#
#   valid loss:		0.69366
#   valid accuracy:	0.50400+/-0.00000
#   valid auc-roc:	0.50808+/-0.00000
#   valid auc-pr:		0.50051+/-0.00000
# Epoch 27 out of 100
# [==============================] 100.0% -- elapsed time=1.04s -- loss=0.68936 -- acc=53.295240%
#
#   valid loss:		0.69415
#   valid accuracy:	0.49700+/-0.00000
#   valid auc-roc:	0.50240+/-0.00000
#   valid auc-pr:		0.49731+/-0.00000
# Epoch 28 out of 100
# [==============================] 100.0% -- elapsed time=1.05s -- loss=0.68736 -- acc=54.409521%
#
#   valid loss:		0.69602
#   valid accuracy:	0.49733+/-0.00000
#   valid auc-roc:	0.49592+/-0.00000
#   valid auc-pr:		0.49318+/-0.00000
# Epoch 29 out of 100
# [==============================] 100.0% -- elapsed time=1.03s -- loss=0.68773 -- acc=54.590479%
#
#   valid loss:		0.69470
#   valid accuracy:	0.49900+/-0.00000
#   valid auc-roc:	0.50211+/-0.00000
#   valid auc-pr:		0.49177+/-0.00000
# Epoch 30 out of 100
# [==============================] 100.0% -- elapsed time=1.05s -- loss=0.68556 -- acc=54.800000%
#
#   valid loss:		0.69486
#   valid accuracy:	0.50200+/-0.00000
#   valid auc-roc:	0.50111+/-0.00000
#   valid auc-pr:		0.49494+/-0.00000
# Epoch 31 out of 100
# [==============================] 100.0% -- elapsed time=1.04s -- loss=0.68678 -- acc=54.500000%
#
#   valid loss:		0.69534
#   valid accuracy:	0.49800+/-0.00000
#   valid auc-roc:	0.50037+/-0.00000
#   valid auc-pr:		0.49209+/-0.00000
# Epoch 32 out of 100
# [==============================] 100.0% -- elapsed time=1.05s -- loss=0.68399 -- acc=55.090479%
#
#   valid loss:		0.69617
#   valid accuracy:	0.49600+/-0.00000
#   valid auc-roc:	0.49962+/-0.00000
#   valid auc-pr:		0.48979+/-0.00000
# Epoch 33 out of 100
# [==============================] 100.0% -- elapsed time=1.04s -- loss=0.68333 -- acc=55.538094%
#
#   valid loss:		0.69661
#   valid accuracy:	0.50533+/-0.00000
#   valid auc-roc:	0.50185+/-0.00000
#   valid auc-pr:		0.49783+/-0.00000
# Epoch 34 out of 100
# [==============================] 100.0% -- elapsed time=1.05s -- loss=0.68309 -- acc=55.633333%
#
#   valid loss:		0.69598
#   valid accuracy:	0.49667+/-0.00000
#   valid auc-roc:	0.49582+/-0.00000
#   valid auc-pr:		0.49263+/-0.00000
# Epoch 35 out of 100
# [==============================] 100.0% -- elapsed time=1.05s -- loss=0.68144 -- acc=55.880958%
#
#   valid loss:		0.69724
#   valid accuracy:	0.49433+/-0.00000
#   valid auc-roc:	0.49411+/-0.00000
#   valid auc-pr:		0.48909+/-0.00000
# Epoch 36 out of 100
# [==============================] 100.0% -- elapsed time=1.05s -- loss=0.67953 -- acc=56.652385%
#
#   valid loss:		0.69914
#   valid accuracy:	0.49733+/-0.00000
#   valid auc-roc:	0.49386+/-0.00000
#   valid auc-pr:		0.49204+/-0.00000
# Epoch 37 out of 100
# [==============================] 100.0% -- elapsed time=1.02s -- loss=0.67763 -- acc=57.304760%
#
#   valid loss:		0.69966
#   valid accuracy:	0.50433+/-0.00000
#   valid auc-roc:	0.49996+/-0.00000
#   valid auc-pr:		0.49507+/-0.00000
# Epoch 38 out of 100
# [==============================] 100.0% -- elapsed time=1.03s -- loss=0.67567 -- acc=57.228573%
#
#   valid loss:		0.70098
#   valid accuracy:	0.50400+/-0.00000
#   valid auc-roc:	0.50438+/-0.00000
#   valid auc-pr:		0.49534+/-0.00000
# Epoch 39 out of 100
# [==============================] 100.0% -- elapsed time=1.03s -- loss=0.67237 -- acc=57.942854%
#
#   valid loss:		0.70139
#   valid accuracy:	0.49567+/-0.00000
#   valid auc-roc:	0.50520+/-0.00000
#   valid auc-pr:		0.49466+/-0.00000
# Epoch 40 out of 100
# [==============================] 100.0% -- elapsed time=1.04s -- loss=0.66939 -- acc=58.704760%
#
#   valid loss:		0.70339
#   valid accuracy:	0.50500+/-0.00000
#   valid auc-roc:	0.50175+/-0.00000
#   valid auc-pr:		0.49273+/-0.00000
# Epoch 41 out of 100
# [==============================] 100.0% -- elapsed time=1.04s -- loss=0.66661 -- acc=59.500000%
#
#   valid loss:		0.70703
#   valid accuracy:	0.49967+/-0.00000
#   valid auc-roc:	0.49972+/-0.00000
#   valid auc-pr:		0.49134+/-0.00000
# Epoch 42 out of 100
# [==============================] 100.0% -- elapsed time=1.03s -- loss=0.66339 -- acc=59.700000%
#
#   valid loss:		0.70924
#   valid accuracy:	0.50467+/-0.00000
#   valid auc-roc:	0.50040+/-0.00000
#   valid auc-pr:		0.49243+/-0.00000
# Epoch 43 out of 100
# [==============================] 100.0% -- elapsed time=1.06s -- loss=0.66237 -- acc=60.519042%
#
#   valid loss:		0.71347
#   valid accuracy:	0.50133+/-0.00000
#   valid auc-roc:	0.49910+/-0.00000
#   valid auc-pr:		0.49171+/-0.00000
# Epoch 44 out of 100
# [==============================] 100.0% -- elapsed time=1.04s -- loss=0.66189 -- acc=59.990479%
#
#   valid loss:		0.71615
#   valid accuracy:	0.49400+/-0.00000
#   valid auc-roc:	0.49322+/-0.00000
#   valid auc-pr:		0.48654+/-0.00000
# Epoch 45 out of 100
# [==============================] 100.0% -- elapsed time=1.04s -- loss=0.65954 -- acc=60.333333%
#
#   valid loss:		0.71841
#   valid accuracy:	0.50067+/-0.00000
#   valid auc-roc:	0.49263+/-0.00000
#   valid auc-pr:		0.48383+/-0.00000
# Epoch 46 out of 100
# [==============================] 100.0% -- elapsed time=1.02s -- loss=0.66002 -- acc=60.400000%
#
#   valid loss:		0.71783
#   valid accuracy:	0.49033+/-0.00000
#   valid auc-roc:	0.49343+/-0.00000
#   valid auc-pr:		0.48452+/-0.00000
# Epoch 47 out of 100
# [==============================] 100.0% -- elapsed time=1.03s -- loss=0.65428 -- acc=61.004760%
#
#   valid loss:		0.72287
#   valid accuracy:	0.50100+/-0.00000
#   valid auc-roc:	0.49539+/-0.00000
#   valid auc-pr:		0.48525+/-0.00000
# Epoch 48 out of 100
# [==============================] 100.0% -- elapsed time=1.04s -- loss=0.65462 -- acc=60.971437%
#
#   valid loss:		0.72216
#   valid accuracy:	0.50200+/-0.00000
#   valid auc-roc:	0.49617+/-0.00000
#   valid auc-pr:		0.48658+/-0.00000
# Epoch 49 out of 100
# [==============================] 100.0% -- elapsed time=1.05s -- loss=0.65401 -- acc=61.123812%
#
#   valid loss:		0.72373
#   valid accuracy:	0.49367+/-0.00000
#   valid auc-roc:	0.49521+/-0.00000
#   valid auc-pr:		0.48761+/-0.00000
# Epoch 50 out of 100
# [==============================] 100.0% -- elapsed time=1.04s -- loss=0.65270 -- acc=61.247625%
#
#   valid loss:		0.72273
#   valid accuracy:	0.49500+/-0.00000
#   valid auc-roc:	0.49965+/-0.00000
#   valid auc-pr:		0.48993+/-0.00000
# Epoch 51 out of 100
# [==============================] 100.0% -- elapsed time=1.01s -- loss=0.65152 -- acc=61.576198%
#
#   valid loss:		0.72528
#   valid accuracy:	0.49900+/-0.00000
#   valid auc-roc:	0.49471+/-0.00000
#   valid auc-pr:		0.48532+/-0.00000
# Epoch 52 out of 100
# [==============================] 100.0% -- elapsed time=1.04s -- loss=0.65054 -- acc=61.757146%
#
#   valid loss:		0.72416
#   valid accuracy:	0.50433+/-0.00000
#   valid auc-roc:	0.49657+/-0.00000
#   valid auc-pr:		0.48790+/-0.00000
# Epoch 53 out of 100
# [==============================] 100.0% -- elapsed time=1.03s -- loss=0.64982 -- acc=61.857146%
#
#   valid loss:		0.72833
#   valid accuracy:	0.49967+/-0.00000
#   valid auc-roc:	0.49551+/-0.00000
#   valid auc-pr:		0.48846+/-0.00000
# Epoch 54 out of 100
# [==============================] 100.0% -- elapsed time=1.03s -- loss=0.64828 -- acc=61.866667%
#
#   valid loss:		0.72545
#   valid accuracy:	0.50067+/-0.00000
#   valid auc-roc:	0.49532+/-0.00000
#   valid auc-pr:		0.48748+/-0.00000
# Epoch 55 out of 100
# [==============================] 100.0% -- elapsed time=1.04s -- loss=0.64372 -- acc=62.861906%
#
#   valid loss:		0.72936
#   valid accuracy:	0.50067+/-0.00000
#   valid auc-roc:	0.49846+/-0.00000
#   valid auc-pr:		0.48888+/-0.00000
# Epoch 56 out of 100
# [==============================] 100.0% -- elapsed time=1.01s -- loss=0.64658 -- acc=62.485719%
#
#   valid loss:		0.72825
#   valid accuracy:	0.49667+/-0.00000
#   valid auc-roc:	0.49699+/-0.00000
#   valid auc-pr:		0.48992+/-0.00000
# Epoch 57 out of 100
# [==============================] 100.0% -- elapsed time=1.02s -- loss=0.64591 -- acc=62.366667%
#
#   valid loss:		0.72941
#   valid accuracy:	0.49000+/-0.00000
#   valid auc-roc:	0.49580+/-0.00000
#   valid auc-pr:		0.48692+/-0.00000
# Epoch 58 out of 100
# [==============================] 100.0% -- elapsed time=1.06s -- loss=0.64356 -- acc=62.490479%
#
#   valid loss:		0.72891
#   valid accuracy:	0.49000+/-0.00000
#   valid auc-roc:	0.49976+/-0.00000
#   valid auc-pr:		0.49121+/-0.00000
# Epoch 59 out of 100
# [==============================] 100.0% -- elapsed time=1.07s -- loss=0.64193 -- acc=62.695240%
#
#   valid loss:		0.72946
#   valid accuracy:	0.49667+/-0.00000
#   valid auc-roc:	0.49986+/-0.00000
#   valid auc-pr:		0.49184+/-0.00000
# Epoch 60 out of 100
# [==============================] 100.0% -- elapsed time=1.06s -- loss=0.64159 -- acc=62.880958%
#
#   valid loss:		0.72919
#   valid accuracy:	0.50267+/-0.00000
#   valid auc-roc:	0.50008+/-0.00000
#   valid auc-pr:		0.49264+/-0.00000
# Epoch 61 out of 100
# [==============================] 100.0% -- elapsed time=1.07s -- loss=0.64232 -- acc=62.600000%
#
#   valid loss:		0.72802
#   valid accuracy:	0.49567+/-0.00000
#   valid auc-roc:	0.50036+/-0.00000
#   valid auc-pr:		0.49248+/-0.00000
# Epoch 62 out of 100
# [==============================] 100.0% -- elapsed time=1.04s -- loss=0.64260 -- acc=62.300000%
#
#   valid loss:		0.72877
#   valid accuracy:	0.50933+/-0.00000
#   valid auc-roc:	0.50302+/-0.00000
#   valid auc-pr:		0.49379+/-0.00000
# Epoch 63 out of 100
# [==============================] 100.0% -- elapsed time=1.03s -- loss=0.63781 -- acc=63.142854%
#
#   valid loss:		0.73113
#   valid accuracy:	0.50633+/-0.00000
#   valid auc-roc:	0.50257+/-0.00000
#   valid auc-pr:		0.49360+/-0.00000
# Epoch 64 out of 100
# [==============================] 100.0% -- elapsed time=1.04s -- loss=0.63971 -- acc=62.714281%
#
#   valid loss:		0.73575
#   valid accuracy:	0.49633+/-0.00000
#   valid auc-roc:	0.49759+/-0.00000
#   valid auc-pr:		0.49092+/-0.00000
# Epoch 65 out of 100
# [==============================] 100.0% -- elapsed time=1.07s -- loss=0.63959 -- acc=62.723812%
#
#   valid loss:		0.73375
#   valid accuracy:	0.50400+/-0.00000
#   valid auc-roc:	0.49877+/-0.00000
#   valid auc-pr:		0.49387+/-0.00000
# Epoch 66 out of 100
# [==============================] 100.0% -- elapsed time=1.07s -- loss=0.63735 -- acc=63.004760%
#
#   valid loss:		0.73382
#   valid accuracy:	0.51100+/-0.00000
#   valid auc-roc:	0.50139+/-0.00000
#   valid auc-pr:		0.49398+/-0.00000
# Epoch 67 out of 100
# [==============================] 100.0% -- elapsed time=1.07s -- loss=0.63931 -- acc=63.123812%
#
#   valid loss:		0.73316
#   valid accuracy:	0.50433+/-0.00000
#   valid auc-roc:	0.50100+/-0.00000
#   valid auc-pr:		0.49340+/-0.00000
# Epoch 68 out of 100
# [==============================] 100.0% -- elapsed time=1.06s -- loss=0.63761 -- acc=63.252385%
#
#   valid loss:		0.73002
#   valid accuracy:	0.50133+/-0.00000
#   valid auc-roc:	0.50277+/-0.00000
#   valid auc-pr:		0.49626+/-0.00000
# Epoch 69 out of 100
# [==============================] 100.0% -- elapsed time=1.04s -- loss=0.63928 -- acc=63.095240%
#
#   valid loss:		0.72937
#   valid accuracy:	0.51400+/-0.00000
#   valid auc-roc:	0.50832+/-0.00000
#   valid auc-pr:		0.49755+/-0.00000
# Epoch 70 out of 100
# [==============================] 100.0% -- elapsed time=1.05s -- loss=0.63484 -- acc=63.533333%
#
#   valid loss:		0.73315
#   valid accuracy:	0.51600+/-0.00000
#   valid auc-roc:	0.50716+/-0.00000
#   valid auc-pr:		0.49587+/-0.00000
# Epoch 71 out of 100
# [==============================] 100.0% -- elapsed time=1.04s -- loss=0.63291 -- acc=63.976198%
#
#   valid loss:		0.73268
#   valid accuracy:	0.51533+/-0.00000
#   valid auc-roc:	0.50895+/-0.00000
#   valid auc-pr:		0.50005+/-0.00000
# Epoch 72 out of 100
# [==============================] 100.0% -- elapsed time=1.02s -- loss=0.63413 -- acc=63.890479%
#
#   valid loss:		0.73204
#   valid accuracy:	0.50300+/-0.00000
#   valid auc-roc:	0.50410+/-0.00000
#   valid auc-pr:		0.49699+/-0.00000
# Epoch 73 out of 100
# [==============================] 100.0% -- elapsed time=1.03s -- loss=0.63354 -- acc=63.642854%
#
#   valid loss:		0.72759
#   valid accuracy:	0.50600+/-0.00000
#   valid auc-roc:	0.50545+/-0.00000
#   valid auc-pr:		0.49800+/-0.00000
# Epoch 74 out of 100
# [==============================] 100.0% -- elapsed time=1.03s -- loss=0.63350 -- acc=63.761906%
#
#   valid loss:		0.73255
#   valid accuracy:	0.51767+/-0.00000
#   valid auc-roc:	0.50909+/-0.00000
#   valid auc-pr:		0.49978+/-0.00000
# Epoch 75 out of 100
# [==============================] 100.0% -- elapsed time=1.05s -- loss=0.63391 -- acc=63.704760%
#
#   valid loss:		0.73048
#   valid accuracy:	0.51200+/-0.00000
#   valid auc-roc:	0.50775+/-0.00000
#   valid auc-pr:		0.50026+/-0.00000
# Epoch 76 out of 100
# [==============================] 100.0% -- elapsed time=1.03s -- loss=0.62982 -- acc=64.133333%
#
#   valid loss:		0.73099
#   valid accuracy:	0.50367+/-0.00000
#   valid auc-roc:	0.50892+/-0.00000
#   valid auc-pr:		0.50211+/-0.00000
# Epoch 77 out of 100
# [==============================] 100.0% -- elapsed time=1.02s -- loss=0.63103 -- acc=63.685719%
#
#   valid loss:		0.72778
#   valid accuracy:	0.51267+/-0.00000
#   valid auc-roc:	0.51086+/-0.00000
#   valid auc-pr:		0.50147+/-0.00000
# Epoch 78 out of 100
# [==============================] 100.0% -- elapsed time=1.02s -- loss=0.62912 -- acc=64.542854%
#
#   valid loss:		0.73094
#   valid accuracy:	0.51100+/-0.00000
#   valid auc-roc:	0.51065+/-0.00000
#   valid auc-pr:		0.50177+/-0.00000
# Epoch 79 out of 100
# [==============================] 100.0% -- elapsed time=1.04s -- loss=0.63010 -- acc=63.509521%
#
#   valid loss:		0.73303
#   valid accuracy:	0.50900+/-0.00000
#   valid auc-roc:	0.50718+/-0.00000
#   valid auc-pr:		0.49990+/-0.00000
# Epoch 80 out of 100
# [==============================] 100.0% -- elapsed time=1.02s -- loss=0.63181 -- acc=64.014281%
#
#   valid loss:		0.72702
#   valid accuracy:	0.51400+/-0.00000
#   valid auc-roc:	0.50864+/-0.00000
#   valid auc-pr:		0.50271+/-0.00000
# Epoch 81 out of 100
# [==============================] 100.0% -- elapsed time=1.03s -- loss=0.62627 -- acc=64.638094%
#
#   valid loss:		0.73288
#   valid accuracy:	0.51200+/-0.00000
#   valid auc-roc:	0.50610+/-0.00000
#   valid auc-pr:		0.49695+/-0.00000
# Epoch 82 out of 100
# [==============================] 100.0% -- elapsed time=1.03s -- loss=0.63127 -- acc=63.752385%
#
#   valid loss:		0.73431
#   valid accuracy:	0.51000+/-0.00000
#   valid auc-roc:	0.50931+/-0.00000
#   valid auc-pr:		0.49964+/-0.00000
# Epoch 83 out of 100
# [==============================] 100.0% -- elapsed time=1.04s -- loss=0.62886 -- acc=64.471437%
#
#   valid loss:		0.73179
#   valid accuracy:	0.50767+/-0.00000
#   valid auc-roc:	0.50806+/-0.00000
#   valid auc-pr:		0.49891+/-0.00000
# Epoch 84 out of 100
# [==============================] 100.0% -- elapsed time=1.03s -- loss=0.62666 -- acc=64.447625%
#
#   valid loss:		0.73294
#   valid accuracy:	0.50700+/-0.00000
#   valid auc-roc:	0.51094+/-0.00000
#   valid auc-pr:		0.50035+/-0.00000
# Epoch 85 out of 100
# [==============================] 100.0% -- elapsed time=1.05s -- loss=0.62428 -- acc=64.533333%
#
#   valid loss:		0.73047
#   valid accuracy:	0.51167+/-0.00000
#   valid auc-roc:	0.51277+/-0.00000
#   valid auc-pr:		0.50216+/-0.00000
# Epoch 86 out of 100
# [==============================] 100.0% -- elapsed time=1.01s -- loss=0.62525 -- acc=64.395240%
#
#   valid loss:		0.73317
#   valid accuracy:	0.50900+/-0.00000
#   valid auc-roc:	0.50948+/-0.00000
#   valid auc-pr:		0.49889+/-0.00000
# Epoch 87 out of 100
# ...
# [==============================] 100.0% -- elapsed time=1.61s -- loss=0.51123 -- acc=75.000000%
#
#   valid loss:		0.87122
#   valid accuracy:	0.51267+/-0.00000
#   valid auc-roc:	0.51746+/-0.00000
#   valid auc-pr:		0.50812+/-0.00000
# Epoch 38 out of 100
# [==============================] 100.0% -- elapsed time=1.60s -- loss=0.50392 -- acc=75.614281%
#
#   valid loss:		0.84476
#   valid accuracy:	0.50733+/-0.00000
#   valid auc-roc:	0.50749+/-0.00000
#   valid auc-pr:		0.49823+/-0.00000
# Epoch 39 out of 100
# [==============================] 100.0% -- elapsed time=1.61s -- loss=0.49530 -- acc=76.161906%
#
#   valid loss:		0.86822
#   valid accuracy:	0.49067+/-0.00000
#   valid auc-roc:	0.50398+/-0.00000
#   valid auc-pr:		0.49784+/-0.00000
# Epoch 40 out of 100
# [==============================] 100.0% -- elapsed time=1.61s -- loss=0.49061 -- acc=76.376198%
#
#   valid loss:		0.82834
#   valid accuracy:	0.51467+/-0.00000
#   valid auc-roc:	0.51471+/-0.00000
#   valid auc-pr:		0.50673+/-0.00000
# Epoch 41 out of 100
# [==============================] 100.0% -- elapsed time=1.60s -- loss=0.49389 -- acc=76.152385%
#
#   valid loss:		0.90525
#   valid accuracy:	0.51033+/-0.00000
#   valid auc-roc:	0.51205+/-0.00000
#   valid auc-pr:		0.50174+/-0.00000
# Epoch 42 out of 100
# [==============================] 100.0% -- elapsed time=1.63s -- loss=0.47821 -- acc=77.314281%
#
#   valid loss:		0.89740
#   valid accuracy:	0.50633+/-0.00000
#   valid auc-roc:	0.50919+/-0.00000
#   valid auc-pr:		0.50010+/-0.00000
# Epoch 43 out of 100
# [==============================] 100.0% -- elapsed time=1.63s -- loss=0.47742 -- acc=76.757146%
#
#   valid loss:		0.84190
#   valid accuracy:	0.51300+/-0.00000
#   valid auc-roc:	0.51742+/-0.00000
#   valid auc-pr:		0.50368+/-0.00000
# Epoch 44 out of 100
# [==============================] 100.0% -- elapsed time=1.60s -- loss=0.46836 -- acc=77.680958%
#
#   valid loss:		0.86817
#   valid accuracy:	0.50233+/-0.00000
#   valid auc-roc:	0.51008+/-0.00000
#   valid auc-pr:		0.49767+/-0.00000
# Epoch 45 out of 100
# [==============================] 100.0% -- elapsed time=1.63s -- loss=0.46013 -- acc=78.690479%
#
#   valid loss:		0.90178
#   valid accuracy:	0.50300+/-0.00000
#   valid auc-roc:	0.50666+/-0.00000
#   valid auc-pr:		0.49622+/-0.00000
# Epoch 46 out of 100
# [==============================] 100.0% -- elapsed time=1.61s -- loss=0.45222 -- acc=79.152385%
#
#   valid loss:		0.90642
#   valid accuracy:	0.50267+/-0.00000
#   valid auc-roc:	0.50726+/-0.00000
#   valid auc-pr:		0.49485+/-0.00000
# Epoch 47 out of 100
# [==============================] 100.0% -- elapsed time=1.61s -- loss=0.45401 -- acc=78.671437%
#
#   valid loss:		0.92530
#   valid accuracy:	0.51433+/-0.00000
#   valid auc-roc:	0.51495+/-0.00000
#   valid auc-pr:		0.50180+/-0.00000
# Epoch 48 out of 100
# [==============================] 100.0% -- elapsed time=1.62s -- loss=0.44945 -- acc=79.066677%
#
#   valid loss:		0.89393
#   valid accuracy:	0.50500+/-0.00000
#   valid auc-roc:	0.51208+/-0.00000
#   valid auc-pr:		0.49979+/-0.00000
# Epoch 49 out of 100
# [==============================] 100.0% -- elapsed time=1.61s -- loss=0.44153 -- acc=79.647625%
#
#   valid loss:		0.90563
#   valid accuracy:	0.51167+/-0.00000
#   valid auc-roc:	0.51148+/-0.00000
#   valid auc-pr:		0.49819+/-0.00000
# Epoch 50 out of 100
# [==============================] 100.0% -- elapsed time=1.63s -- loss=0.44361 -- acc=79.623812%
#
#   valid loss:		0.89684
#   valid accuracy:	0.51133+/-0.00000
#   valid auc-roc:	0.51760+/-0.00000
#   valid auc-pr:		0.50362+/-0.00000
# Epoch 51 out of 100
# [==============================] 100.0% -- elapsed time=1.62s -- loss=0.43410 -- acc=80.176198%
#
#   valid loss:		0.90490
#   valid accuracy:	0.50933+/-0.00000
#   valid auc-roc:	0.51693+/-0.00000
#   valid auc-pr:		0.50344+/-0.00000
# Epoch 52 out of 100
# [==============================] 100.0% -- elapsed time=1.62s -- loss=0.43294 -- acc=80.219052%
#
#   valid loss:		0.91161
#   valid accuracy:	0.51133+/-0.00000
#   valid auc-roc:	0.51538+/-0.00000
#   valid auc-pr:		0.50458+/-0.00000
# Epoch 53 out of 100
# [==============================] 100.0% -- elapsed time=1.61s -- loss=0.42420 -- acc=80.619052%
#
#   valid loss:		0.91244
#   valid accuracy:	0.50567+/-0.00000
#   valid auc-roc:	0.51481+/-0.00000
#   valid auc-pr:		0.50397+/-0.00000
# Epoch 54 out of 100
# [==============================] 100.0% -- elapsed time=1.62s -- loss=0.42636 -- acc=80.361906%
#
#   valid loss:		0.89260
#   valid accuracy:	0.51300+/-0.00000
#   valid auc-roc:	0.51849+/-0.00000
#   valid auc-pr:		0.50676+/-0.00000
# Epoch 55 out of 100
# [==============================] 100.0% -- elapsed time=1.61s -- loss=0.42527 -- acc=80.300000%
#
#   valid loss:		0.99681
#   valid accuracy:	0.50967+/-0.00000
#   valid auc-roc:	0.51941+/-0.00000
#   valid auc-pr:		0.50638+/-0.00000
# Epoch 56 out of 100
# [==============================] 100.0% -- elapsed time=1.63s -- loss=0.41561 -- acc=80.857146%
#
#   valid loss:		0.94724
#   valid accuracy:	0.51833+/-0.00000
#   valid auc-roc:	0.51806+/-0.00000
#   valid auc-pr:		0.50651+/-0.00000
# Epoch 57 out of 100
# [==============================] 100.0% -- elapsed time=1.63s -- loss=0.41206 -- acc=81.223812%
#
#   valid loss:		0.92348
#   valid accuracy:	0.50200+/-0.00000
#   valid auc-roc:	0.51363+/-0.00000
#   valid auc-pr:		0.50255+/-0.00000
# Epoch 58 out of 100
# [==============================] 100.0% -- elapsed time=1.62s -- loss=0.40685 -- acc=81.614281%
#
#   valid loss:		0.93345
#   valid accuracy:	0.51700+/-0.00000
#   valid auc-roc:	0.51312+/-0.00000
#   valid auc-pr:		0.50249+/-0.00000
# Epoch 59 out of 100
# [==============================] 100.0% -- elapsed time=1.61s -- loss=0.41047 -- acc=81.347625%
#
#   valid loss:		0.92436
#   valid accuracy:	0.51467+/-0.00000
#   valid auc-roc:	0.51455+/-0.00000
#   valid auc-pr:		0.50617+/-0.00000
# Epoch 60 out of 100
# [==============================] 100.0% -- elapsed time=1.62s -- loss=0.40152 -- acc=81.733333%
#
#   valid loss:		0.98730
#   valid accuracy:	0.51133+/-0.00000
#   valid auc-roc:	0.51200+/-0.00000
#   valid auc-pr:		0.49918+/-0.00000
# Epoch 61 out of 100
# [==============================] 100.0% -- elapsed time=1.60s -- loss=0.40696 -- acc=81.361906%
#
#   valid loss:		0.94318
#   valid accuracy:	0.51400+/-0.00000
#   valid auc-roc:	0.51408+/-0.00000
#   valid auc-pr:		0.50329+/-0.00000
# Epoch 62 out of 100
# [==============================] 100.0% -- elapsed time=1.62s -- loss=0.40300 -- acc=81.747625%
#
#   valid loss:		0.92143
#   valid accuracy:	0.51433+/-0.00000
#   valid auc-roc:	0.51732+/-0.00000
#   valid auc-pr:		0.50660+/-0.00000
# Epoch 63 out of 100
# [==============================] 100.0% -- elapsed time=1.61s -- loss=0.40056 -- acc=81.919052%
#
#   valid loss:		0.93244
#   valid accuracy:	0.51200+/-0.00000
#   valid auc-roc:	0.52020+/-0.00000
#   valid auc-pr:		0.50699+/-0.00000
# Epoch 64 out of 100
# [==============================] 100.0% -- elapsed time=1.60s -- loss=0.39097 -- acc=82.195240%
#
#   valid loss:		0.95442
#   valid accuracy:	0.51633+/-0.00000
#   valid auc-roc:	0.52185+/-0.00000
#   valid auc-pr:		0.50720+/-0.00000
# Epoch 65 out of 100
# [==============================] 100.0% -- elapsed time=1.63s -- loss=0.39256 -- acc=82.271437%
#
#   valid loss:		0.95647
#   valid accuracy:	0.50500+/-0.00000
#   valid auc-roc:	0.51813+/-0.00000
#   valid auc-pr:		0.50936+/-0.00000
# Epoch 66 out of 100
# [==============================] 100.0% -- elapsed time=1.61s -- loss=0.38836 -- acc=82.633333%
#
#   valid loss:		0.97466
#   valid accuracy:	0.51667+/-0.00000
#   valid auc-roc:	0.52070+/-0.00000
#   valid auc-pr:		0.50734+/-0.00000
# Epoch 67 out of 100
# [==============================] 100.0% -- elapsed time=1.62s -- loss=0.38675 -- acc=82.623812%
#
#   valid loss:		0.99274
#   valid accuracy:	0.50567+/-0.00000
#   valid auc-roc:	0.51030+/-0.00000
#   valid auc-pr:		0.49759+/-0.00000
# Epoch 68 out of 100
# [==============================] 100.0% -- elapsed time=1.62s -- loss=0.38562 -- acc=82.604760%
#
#   valid loss:		0.93963
#   valid accuracy:	0.51267+/-0.00000
#   valid auc-roc:	0.51635+/-0.00000
#   valid auc-pr:		0.50439+/-0.00000
# Epoch 69 out of 100
# [==============================] 100.0% -- elapsed time=1.63s -- loss=0.38266 -- acc=82.895240%
#
#   valid loss:		0.94491
#   valid accuracy:	0.51067+/-0.00000
#   valid auc-roc:	0.52143+/-0.00000
#   valid auc-pr:		0.50838+/-0.00000
# Epoch 70 out of 100
# [==============================] 100.0% -- elapsed time=1.62s -- loss=0.38070 -- acc=82.895240%
#
#   valid loss:		0.96809
#   valid accuracy:	0.51133+/-0.00000
#   valid auc-roc:	0.52217+/-0.00000
#   valid auc-pr:		0.50935+/-0.00000
# Epoch 71 out of 100
# [==============================] 100.0% -- elapsed time=1.61s -- loss=0.38243 -- acc=82.966667%
#
#   valid loss:		1.00283
#   valid accuracy:	0.51800+/-0.00000
#   valid auc-roc:	0.51670+/-0.00000
#   valid auc-pr:		0.50677+/-0.00000
# Epoch 72 out of 100
# [==============================] 100.0% -- elapsed time=1.63s -- loss=0.37422 -- acc=83.319052%
#
#   valid loss:		0.95268
#   valid accuracy:	0.51500+/-0.00000
#   valid auc-roc:	0.51549+/-0.00000
#   valid auc-pr:		0.50629+/-0.00000
# Epoch 73 out of 100
# [==============================] 100.0% -- elapsed time=1.61s -- loss=0.37741 -- acc=83.257146%
#
#   valid loss:		0.94606
#   valid accuracy:	0.51767+/-0.00000
#   valid auc-roc:	0.51599+/-0.00000
#   valid auc-pr:		0.50442+/-0.00000
# Epoch 74 out of 100
# [==============================] 100.0% -- elapsed time=1.63s -- loss=0.37863 -- acc=83.085719%
#
#   valid loss:		0.96334
#   valid accuracy:	0.52033+/-0.00000
#   valid auc-roc:	0.52170+/-0.00000
#   valid auc-pr:		0.50894+/-0.00000
# Epoch 75 out of 100
# [==============================] 100.0% -- elapsed time=1.63s -- loss=0.36737 -- acc=83.619052%
#
#   valid loss:		0.98995
#   valid accuracy:	0.51600+/-0.00000
#   valid auc-roc:	0.52418+/-0.00000
#   valid auc-pr:		0.51109+/-0.00000
# Epoch 76 out of 100
# [==============================] 100.0% -- elapsed time=1.60s -- loss=0.36913 -- acc=83.438094%
#
#   valid loss:		0.97695
#   valid accuracy:	0.51000+/-0.00000
#   valid auc-roc:	0.51730+/-0.00000
#   valid auc-pr:		0.50496+/-0.00000
# Epoch 77 out of 100
# [==============================] 100.0% -- elapsed time=1.62s -- loss=0.36965 -- acc=83.728573%
#
#   valid loss:		0.94161
#   valid accuracy:	0.51000+/-0.00000
#   valid auc-roc:	0.51717+/-0.00000
#   valid auc-pr:		0.50697+/-0.00000
# Epoch 78 out of 100
# [==============================] 100.0% -- elapsed time=1.60s -- loss=0.36429 -- acc=83.933333%
#
#   valid loss:		0.95532
#   valid accuracy:	0.51867+/-0.00000
#   valid auc-roc:	0.52207+/-0.00000
#   valid auc-pr:		0.50907+/-0.00000
# Epoch 79 out of 100
# [==============================] 100.0% -- elapsed time=1.61s -- loss=0.36452 -- acc=84.052385%
#
#   valid loss:		0.96937
#   valid accuracy:	0.51133+/-0.00000
#   valid auc-roc:	0.52158+/-0.00000
#   valid auc-pr:		0.50938+/-0.00000
# Epoch 80 out of 100
# [==============================] 100.0% -- elapsed time=1.62s -- loss=0.36614 -- acc=83.909521%
#
#   valid loss:		0.99851
#   valid accuracy:	0.51267+/-0.00000
#   valid auc-roc:	0.51423+/-0.00000
#   valid auc-pr:		0.50343+/-0.00000
# Epoch 81 out of 100
# [==============================] 100.0% -- elapsed time=1.61s -- loss=0.36437 -- acc=83.838094%
#
#   valid loss:		0.98131
#   valid accuracy:	0.51367+/-0.00000
#   valid auc-roc:	0.51998+/-0.00000
#   valid auc-pr:		0.50844+/-0.00000
# Epoch 82 out of 100
# [==============================] 100.0% -- elapsed time=1.60s -- loss=0.35775 -- acc=84.585719%
#
#   valid loss:		0.97436
#   valid accuracy:	0.51100+/-0.00000
#   valid auc-roc:	0.51331+/-0.00000
#   valid auc-pr:		0.50249+/-0.00000
# Epoch 83 out of 100
# [==============================] 100.0% -- elapsed time=1.62s -- loss=0.35731 -- acc=84.428573%
#
#   valid loss:		0.99543
#   valid accuracy:	0.51233+/-0.00000
#   valid auc-roc:	0.51825+/-0.00000
#   valid auc-pr:		0.50574+/-0.00000
# Epoch 84 out of 100
# [==============================] 100.0% -- elapsed time=1.60s -- loss=0.35738 -- acc=84.323812%
#
#   valid loss:		0.97168
#   valid accuracy:	0.50833+/-0.00000
#   valid auc-roc:	0.51746+/-0.00000
#   valid auc-pr:		0.50591+/-0.00000
# Epoch 85 out of 100
# [==============================] 100.0% -- elapsed time=1.62s -- loss=0.35669 -- acc=84.452385%
#
#   valid loss:		1.01707
#   valid accuracy:	0.50567+/-0.00000
#   valid auc-roc:	0.51230+/-0.00000
#   valid auc-pr:		0.49819+/-0.00000
# Epoch 86 out of 100
# [==============================] 100.0% -- elapsed time=1.63s -- loss=0.35676 -- acc=84.228573%
#
#   valid loss:		0.97797
#   valid accuracy:	0.51300+/-0.00000
#   valid auc-roc:	0.51055+/-0.00000
#   valid auc-pr:		0.49838+/-0.00000
# Epoch 87 out of 100
# [==============================] 100.0% -- elapsed time=1.60s -- loss=0.35116 -- acc=84.652385%
#
#   valid loss:		0.97857
#   valid accuracy:	0.50200+/-0.00000
#   valid auc-roc:	0.51030+/-0.00000
#   valid auc-pr:		0.50067+/-0.00000
# Epoch 88 out of 100
# [==============================] 100.0% -- elapsed time=1.61s -- loss=0.34727 -- acc=84.671437%
#
#   valid loss:		1.00974
#   valid accuracy:	0.51133+/-0.00000
#   valid auc-roc:	0.51610+/-0.00000
#   valid auc-pr:		0.49950+/-0.00000
# Epoch 89 out of 100
# [==============================] 100.0% -- elapsed time=1.61s -- loss=0.35937 -- acc=84.180958%
#
#   valid loss:		0.97706
#   valid accuracy:	0.50433+/-0.00000
#   valid auc-roc:	0.50677+/-0.00000
#   valid auc-pr:		0.49753+/-0.00000
# Epoch 90 out of 100
# [==============================] 100.0% -- elapsed time=1.61s -- loss=0.35389 -- acc=84.585719%
#
#   valid loss:		1.01767
#   valid accuracy:	0.50367+/-0.00000
#   valid auc-roc:	0.50612+/-0.00000
#   valid auc-pr:		0.49542+/-0.00000
# Epoch 91 out of 100
# [==============================] 100.0% -- elapsed time=1.63s -- loss=0.34427 -- acc=84.923812%
#
#   valid loss:		0.99383
#   valid accuracy:	0.50267+/-0.00000
#   valid auc-roc:	0.51011+/-0.00000
#   valid auc-pr:		0.49653+/-0.00000
# Epoch 92 out of 100
# [==============================] 100.0% -- elapsed time=1.61s -- loss=0.34802 -- acc=84.909521%
#
#   valid loss:		0.97491
#   valid accuracy:	0.51367+/-0.00000
#   valid auc-roc:	0.51300+/-0.00000
#   valid auc-pr:		0.50168+/-0.00000
# Epoch 93 out of 100
# [==============================] 100.0% -- elapsed time=1.60s -- loss=0.34104 -- acc=85.461916%
#
#   valid loss:		0.98916
#   valid accuracy:	0.50733+/-0.00000
#   valid auc-roc:	0.50631+/-0.00000
#   valid auc-pr:		0.49769+/-0.00000
# Epoch 94 out of 100
# [==============================] 100.0% -- elapsed time=1.63s -- loss=0.34463 -- acc=85.104760%
#
#   valid loss:		0.99593
#   valid accuracy:	0.50967+/-0.00000
#   valid auc-roc:	0.51635+/-0.00000
#   valid auc-pr:		0.50234+/-0.00000
# Epoch 95 out of 100
# [==============================] 100.0% -- elapsed time=1.61s -- loss=0.33799 -- acc=85.276198%
#
#   valid loss:		1.03200
#   valid accuracy:	0.50933+/-0.00000
#   valid auc-roc:	0.51456+/-0.00000
#   valid auc-pr:		0.50011+/-0.00000
# Epoch 96 out of 100
# [==============================] 100.0% -- elapsed time=1.61s -- loss=0.34403 -- acc=85.142864%
#
#   valid loss:		1.00441
#   valid accuracy:	0.51100+/-0.00000
#   valid auc-roc:	0.51850+/-0.00000
#   valid auc-pr:		0.50330+/-0.00000
# Epoch 97 out of 100
# [==============================] 100.0% -- elapsed time=1.62s -- loss=0.33929 -- acc=85.309521%
#
#   valid loss:		1.04178
#   valid accuracy:	0.51433+/-0.00000
#   valid auc-roc:	0.51709+/-0.00000
#   valid auc-pr:		0.50341+/-0.00000
# Epoch 98 out of 100
# [==============================] 100.0% -- elapsed time=1.60s -- loss=0.34423 -- acc=84.761906%
#
#   valid loss:		0.99578
#   valid accuracy:	0.50833+/-0.00000
#   valid auc-roc:	0.51705+/-0.00000
#   valid auc-pr:		0.50235+/-0.00000
# Epoch 99 out of 100
# [==============================] 100.0% -- elapsed time=1.61s -- loss=0.34273 -- acc=85.238104%
#
#   valid loss:		1.00332
#   valid accuracy:	0.50467+/-0.00000
#   valid auc-roc:	0.51490+/-0.00000
#   valid auc-pr:		0.50135+/-0.00000
# Epoch 100 out of 100
# [==============================] 100.0% -- elapsed time=1.60s -- loss=0.33709 -- acc=85.376198%
#
#   valid loss:		1.03232
#   valid accuracy:	0.51000+/-0.00000
#   valid auc-roc:	0.51228+/-0.00000
#   valid auc-pr:		0.49933+/-0.00000

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os, sys
import numpy as np
import helper
import tensorflow as tf
from deepomics import neuralnetwork as nn
from deepomics import utils, fit, visualize, saliency, metrics
import helper
sys.path.append('../..')
import mutagenesisfunctions as mf

#-----------------------------------------------------------------------------------------------

def fom_heatmap(X, layer, alphabet, nntrainer, sess, eps=1e-7):
    
    def mutate(sequence, seq_length, dims):
        num_mutations = seq_length * dims
        hotplot_mutations = np.zeros((num_mutations,seq_length,1,dims)) 

        for position in range(seq_length):
            for nuc in range(dims):
                mut_seq = np.copy(sequence)          
                mut_seq[0, position, 0, :] = np.zeros(dims)
                mut_seq[0, position, 0, nuc] = 1.0

                hotplot_mutations[(position*dims)+nuc] = mut_seq
        return hotplot_mutations

    #first mutate the sequence
    X_mut = mutate(X, X.shape[1], X.shape[3])

    #take all the mutations and assign them into a dict for deepomics
    mutations = {'inputs': X_mut, 'targets': np.ones((X_mut.shape[0], 1))}
    #Get output or logits activations for the mutations
    mut_predictions = nntrainer.get_activations(sess, mutations, layer=layer)

    #take the WT and put it into a dict for deepomics
    WT = {'inputs': X, 'targets': np.ones((X.shape[0], 1))}
    #Get output or logits activations for the WT sequence
    predictions = nntrainer.get_activations(sess, WT, layer=layer)

    #shape the predictions of the mutations into the shape of a heatmap
    heat_mut = mut_predictions.reshape(X.shape[1],4).T
    
    #normalize the heat map rearrangement by minusing it by the true prediction score of that test sequence
    #norm_heat_mut = heat_mut - predictions[0] + eps
    #norm_heat_mut = utils.normalize_pwm(norm_heat_mut, factor=4)

    return (heat_mut)
#-----------------------------------------------------------------------------------------------

'''
This script outputs the First Order Mutagenesis scores for every model and every regularization mode over every positively labelled sequence.
It outputs a single np.array with the shape (num_models, num_reg, num_pos, dims, seqlen)

It will also output an array in the shape (num_models, num_reg) showing the name of each model for ease of indexing into the larger model.

'''
#------------------------------------------------------------------------------------------------

all_models = ['DistNet', 'LocalNet', 'DeepBind', 'StandardNet']
num_models = len(all_models) # number of models
dropout_status = [True, True, 	False, 	False, 	False, True,  True,  False]
l2_status = 	 [True, False, 	True, 	False, 	False, True,  False, True]
bn_status = 	 [True, False, 	False, 	True, 	False, False, True,  True]
num_reg = len(dropout_status) # number of regularization types

# save path
results_path = '../results'
params_path = utils.make_directory(results_path, 'model_params')

# dataset path
data_path = '../data/Synthetic_dataset.h5'

# load dataset
train, valid, test = helper.load_synthetic_dataset(data_path)
#Get the indices of correctly labelled sequences
right_index = np.where(test['targets'][:,0]==1)[0]
num_pos = len(right_index) # number of positively labelled sequences

# get data shapes
input_shape = list(train['inputs'].shape)
input_shape[0] = None

_, seqlen, _, dims = test['inputs'].shape # the length of each sequence and the number of dimensions

#initialize an array to hold the FoM results
full_fom_predictions = np.zeros((num_models, num_reg, num_pos, dims, seqlen))

# loop through models
for m, model_name in enumerate(all_models):

    #loop through every regularization type
    for r in range(len(dropout_status)):
        tf.reset_default_graph()
        print('model: ' + model_name)

        # compile neural trainer
        name = model_name
        if dropout_status[i]:
            name += '_do'
        if l2_status[i]:
            name += '_l2'
        if bn_status[i]:
            name += '_bn'
        model_path = utils.make_directory(params_path, model_name)
        file_path = os.path.join(model_path, name)

        # load model parameters
        model_layers, optimization, _ = helper.load_model(model_name, 
                                                          input_shape,
                                                          dropout_status[i], 
                                                          l2_status[i], 
                                                          bn_status[i])
        # build neural network class
        nnmodel = nn.NeuralNet(seed=247)
        nnmodel.build_layers(model_layers, optimization, supervised=True)

        # compile neural trainers
        nntrainer = nn.NeuralTrainer(nnmodel, save='best', file_path=file_path)

        # initialize session
        sess = utils.initialize_session()

        # load best parameters
        nntrainer.set_best_parameters(sess)
        
        for p, index in enumerate(right_index):
            #Extract a sequence and perform First Order Mutagenesis
            X = np.expand_dims(test['inputs'][index], axis=0)
            
            full_fom_predictions[m, r, p, :, :] = fom_heatmap(X, 'output', 'dna', nntrainer, sess)
# Out:
# loading training data
# loading cross-validation data
# loading test data
# model: DistNet
# loading model from:  ../results/model_params/DistNet/DistNet_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/DistNet/DistNet_l2_bn_best.ckpt
# model: DistNet
# loading model from:  ../results/model_params/DistNet/DistNet_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/DistNet/DistNet_l2_bn_best.ckpt
# model: DistNet
# loading model from:  ../results/model_params/DistNet/DistNet_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/DistNet/DistNet_l2_bn_best.ckpt
# model: DistNet
# loading model from:  ../results/model_params/DistNet/DistNet_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/DistNet/DistNet_l2_bn_best.ckpt
# model: DistNet
# loading model from:  ../results/model_params/DistNet/DistNet_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/DistNet/DistNet_l2_bn_best.ckpt
# model: DistNet
# loading model from:  ../results/model_params/DistNet/DistNet_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/DistNet/DistNet_l2_bn_best.ckpt
# model: DistNet
# loading model from:  ../results/model_params/DistNet/DistNet_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/DistNet/DistNet_l2_bn_best.ckpt
# model: DistNet
# loading model from:  ../results/model_params/DistNet/DistNet_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/DistNet/DistNet_l2_bn_best.ckpt
# model: LocalNet
# loading model from:  ../results/model_params/LocalNet/LocalNet_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/LocalNet/LocalNet_l2_bn_best.ckpt
# model: LocalNet
# loading model from:  ../results/model_params/LocalNet/LocalNet_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/LocalNet/LocalNet_l2_bn_best.ckpt
# model: LocalNet
# loading model from:  ../results/model_params/LocalNet/LocalNet_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/LocalNet/LocalNet_l2_bn_best.ckpt
# model: LocalNet
# loading model from:  ../results/model_params/LocalNet/LocalNet_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/LocalNet/LocalNet_l2_bn_best.ckpt
# model: LocalNet
# loading model from:  ../results/model_params/LocalNet/LocalNet_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/LocalNet/LocalNet_l2_bn_best.ckpt
# model: LocalNet
# loading model from:  ../results/model_params/LocalNet/LocalNet_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/LocalNet/LocalNet_l2_bn_best.ckpt
# model: LocalNet
# loading model from:  ../results/model_params/LocalNet/LocalNet_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/LocalNet/LocalNet_l2_bn_best.ckpt
# model: LocalNet
# loading model from:  ../results/model_params/LocalNet/LocalNet_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/LocalNet/LocalNet_l2_bn_best.ckpt
# model: DeepBind
# loading model from:  ../results/model_params/DeepBind/DeepBind_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/DeepBind/DeepBind_l2_bn_best.ckpt
# model: DeepBind
# loading model from:  ../results/model_params/DeepBind/DeepBind_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/DeepBind/DeepBind_l2_bn_best.ckpt
# model: DeepBind
# loading model from:  ../results/model_params/DeepBind/DeepBind_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/DeepBind/DeepBind_l2_bn_best.ckpt
# model: DeepBind
# loading model from:  ../results/model_params/DeepBind/DeepBind_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/DeepBind/DeepBind_l2_bn_best.ckpt
# model: DeepBind
# loading model from:  ../results/model_params/DeepBind/DeepBind_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/DeepBind/DeepBind_l2_bn_best.ckpt
# model: DeepBind
# loading model from:  ../results/model_params/DeepBind/DeepBind_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/DeepBind/DeepBind_l2_bn_best.ckpt
# model: DeepBind
# loading model from:  ../results/model_params/DeepBind/DeepBind_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/DeepBind/DeepBind_l2_bn_best.ckpt
# model: DeepBind
# loading model from:  ../results/model_params/DeepBind/DeepBind_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/DeepBind/DeepBind_l2_bn_best.ckpt
# model: StandardNet
# loading model from:  ../results/model_params/StandardNet/StandardNet_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/StandardNet/StandardNet_l2_bn_best.ckpt
# model: StandardNet
# loading model from:  ../results/model_params/StandardNet/StandardNet_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/StandardNet/StandardNet_l2_bn_best.ckpt
# model: StandardNet
# loading model from:  ../results/model_params/StandardNet/StandardNet_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/StandardNet/StandardNet_l2_bn_best.ckpt
# model: StandardNet
# loading model from:  ../results/model_params/StandardNet/StandardNet_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/StandardNet/StandardNet_l2_bn_best.ckpt
# model: StandardNet
# loading model from:  ../results/model_params/StandardNet/StandardNet_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/StandardNet/StandardNet_l2_bn_best.ckpt
# model: StandardNet
# loading model from:  ../results/model_params/StandardNet/StandardNet_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/StandardNet/StandardNet_l2_bn_best.ckpt
# model: StandardNet
# loading model from:  ../results/model_params/StandardNet/StandardNet_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/StandardNet/StandardNet_l2_bn_best.ckpt
# model: StandardNet
# loading model from:  ../results/model_params/StandardNet/StandardNet_l2_bn_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/model_params/StandardNet/StandardNet_l2_bn_best.ckpt
# making directory: ../results/FoM_full_analysis.hff5
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-0f6d37a31654> in <module>()
#     138 save_path = utils.make_directory(results_path, 'FoM_full_analysis' + '.hff5')
#     139 hdf5path = os.path.join(save_path, 'full_fom_predictions')
# --> 140 with h5py.File(hdf5path, 'w') as f:
#     141     f.create_dataset('full_fom', data=full_fom_predictions.astype(np.float32), compression='gzip')
#     142
#
# NameError: name 'h5py' is not defined

# %%
import h5py

#save the array
save_path = utils.make_directory(results_path, 'FoM_full_analysis')
hdf5path = os.path.join(save_path, 'full_fom_predictions'+'.hdf5')
with h5py.File(hdf5path, 'w') as f:
    f.create_dataset('full_fom', data=full_fom_predictions.astype(np.float32), compression='gzip')
# Out:
# making directory: ../results/FoM_full_analysis

# %%
data_path = hdf5path
with h5py.File(data_path, 'r') as dataset:
    full_fom = np.array(dataset['full_fom'])

# %%
full_fom.shape
# Out:
# (4, 8, 3030, 4, 200)
